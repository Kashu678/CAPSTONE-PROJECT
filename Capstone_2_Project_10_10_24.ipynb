# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/accidentRate.csv')

# %%
All_India = df['All India'].sum()
percentage_accidents = (df['All India'] / All_India) * 100

print(percentage_accidents)
sns.set_style('whitegrid')
plt.figure(figsize=(10, 6))
sns.barplot(x=df['States/Uts'], y=percentage_accidents)
plt.title('Percentage of Road Accidents during all the year')
plt.xlabel('States/Uts')
plt.ylabel('Percentage of Road Accidents')
plt.xticks(rotation=90)
plt.show()
# Out:
# 0     4.811053
# 1     5.188149
# 2     5.458419
# 3     6.140043
# 4     6.613637
# 5     6.968636
# 6     7.256427
# 7     7.816384
# 8     7.951061
# 9     8.047493
# 10    8.014543
# 11    8.226300
# 12    8.611895
# 13    8.895960
# Name: All India, dtype: float64

# %%
df = pd.read_csv('/content/roadAccStats13-16.csv')

# Q3- The highest number of accident states and least number of accident states.

state_with_highest_accidents = df.loc[df['States/UTs'].idxmax()]

state_with_least_accidents = df.loc[df['States/UTs'].idxmin()]

print("State with the highest number of accidents:", state_with_highest_accidents)
print("State with the least number of accidents:", state_with_least_accidents)
# Out:
# State with the highest number of accidents: SI. No.                                                                  29
# States/UTs                                                      West Bengal
# State/UT-Wise Total Number of Road Accidents during - 2013          12414.0
# State/UT-Wise Total Number of Road Accidents during - 2014            12875
# State/UT-Wise Total Number of Road Accidents during - 2015            13208
# State/UT-Wise Total Number of Road Accidents during - 2016            13580
# Share of States/UTs in Total Number of Road Accidents - 2013            2.6
# Share of States/UTs in Total Number of Road Accidents - 2014            2.6
# Share of States/UTs in Total Number of Road Accidents - 2015            2.6
# Share of States/UTs in Total Number of Road Accidents - 2016            2.8
# Total Number of Accidents Per Lakh Population - 2013                   13.6
# Total Number of Accidents Per Lakh Population - 2014                   14.0
# ...

# %%
df.describe()
# Out:
#        State/UT-Wise Total Number of Road Accidents during - 2013  \
# count                                          36.000000
# mean                                        27026.444444
# std                                         80979.146929
# min                                             1.000000
# 25%                                           496.250000
# 50%                                          6390.000000
# 75%                                         24041.750000
# max                                        486476.000000
#
#        State/UT-Wise Total Number of Road Accidents during - 2014  \
# count                                          37.000000
# mean                                        26454.054054
# std                                         80289.994996
# min                                             1.000000
# 25%                                           542.000000
# 50%                                          6391.000000
# ...

# %%
df.groupby('States/UTs')[['Total Number of Accidents Per Lakh Population - 2013','Total Number of Accidents Per Lakh Population - 2014',
'Total Number of Accidents Per Lakh Population - 2015','Total Number of Accidents Per Lakh Population - 2016']].mean()
# Out:
#                            Total Number of Accidents Per Lakh Population - 2013  \
# States/UTs
# Andaman & Nicobar Islands                                               38.5
# Andhra Pradesh                                                          50.4
# Arunachal Pradesh                                                       24.3
# Assam                                                                   23.0
# Bihar                                                                   10.2
# Chandigarh                                                              25.9
# Chhattisgarh                                                            54.8
# Dadra & Nagar Haveli                                                    23.5
# Daman & Diu                                                             20.1
# Delhi                                                                   38.7
# Goa                                                                    229.9
# ...

# %%
df1 = pd.read_csv('/content/Details_of_road_accident_deaths_by_situation_state_2014.csv')

# %%
# Q4 - Offenders and victims who died according to gender as well the as the total deaths
# Offenders
gender_death_offenders = df1.groupby(['Offenders (Driver/Pedestrian) Died_Male',
                                  'Offenders (Driver/Pedestrian) Died_Female',
                                  'Offenders (Driver/Pedestrian) Died_Transgender'])[
                                  'Offenders (Driver/Pedestrian) Died_Total'].sum()

total_deaths = gender_death_offenders.sum()
gender_death_offenders['Total Deaths'] = total_deaths
print(gender_death_offenders)
# Out:
# Offenders (Driver/Pedestrian) Died_Male  Offenders (Driver/Pedestrian) Died_Female  Offenders (Driver/Pedestrian) Died_Transgender
# 0                                        0                                          0                                                      0
#                                          1                                          0                                                      6
# 1                                        0                                          0                                                    100
#                                          1                                          0                                                     14
#                                          2                                          0                                                      6
#                                                                                                                                        ...
# ...

# %%
# Victims
gender_death_victims = df1.groupby(['Victims Died_Male',
                                    'Victims Died_Female',
                                    'Victims Died_Transgender'])[
                                    'Victims Died_Total'].sum()

total_deaths = gender_death_victims.sum()
gender_death_victims['Total Deaths'] = total_deaths
print(gender_death_victims)
# Out:
# Victims Died_Male  Victims Died_Female  Victims Died_Transgender
# 0                  0                    0                                 0
#                    1                    0                                13
#                    2                    0                                10
#                    3                    0                                 3
#                    9                    0                                 9
#                                                                      ...
# 79772              15552                15                            95339
# 81148              15704                15                            96867
# 88042              17385                17                           105444
# 89683              17574                17                           107274
# Total Deaths                                                        1218765
# Name: Victims Died_Total, Length: 779, dtype: int64

# %%
df2 = pd.read_csv('//content/Persons_killed_due_to_Non-use_of_Safety_Device_2016.csv')

# %%
# Q5- Percentage of Deaths occurring due to non-wearing of helmets between male and
# female.

male_deaths =df2['Non-wearing of Helmet - Male'].sum()
female_deaths = df2['Non-wearing of Helmet - Female'].sum()
total_deaths = df2['Non-wearing of Helmet - Total'].sum()
male_percentage = (male_deaths / total_deaths) * 100
female_percentage = (female_deaths / total_deaths) * 100
print("Percentage of Deaths occurring due to non-wearing of helmets by male:", male_percentage)
print("Percentage of Deaths occurring due to non-wearing of helmets by female:", female_percentage)

# Percentage with vizualization.
plt.figure(figsize=(7, 6))
sns.barplot(x=['Male', 'Female'], y=[male_percentage, female_percentage])
plt.title('Percentage of Deaths occurring due to non-wearing of helmets')
plt.xlabel("Gender")
plt.ylabel("Number of percentage")
plt.text(0, male_percentage, f'{male_percentage:.2f}%', ha='center', va='bottom')
plt.text(1, female_percentage, f'{female_percentage:.2f}%', ha='center', va='bottom')
plt.show()
# Out:
# Percentage of Deaths occurring due to non-wearing of helmets by male: 85.01233349777996
# Percentage of Deaths occurring due to non-wearing of helmets by female: 14.987666502220028

# %%
df3 = pd.read_excel('/content/accidents03-16-New.xls')

# %%
# Q-6 The number of accidents happening per state from the year 2003 to 2016.
df3.describe()
# Out:
#                2003          2004          2005          2006           2007  \
# count     36.000000     36.000000     36.000000     36.000000      36.000000
# mean    4088.277778   4408.722222   4638.388889   5217.611111    5620.055556
# std    12196.478472  13159.761523  13827.916745  15561.914618   16755.517803
# min        0.000000      0.000000      0.000000      1.000000       0.000000
# 25%      127.500000    102.750000    112.750000    126.500000     106.000000
# 50%     1348.000000   1378.000000   1441.000000   1705.500000    1780.500000
# 75%     3008.500000   3316.750000   4209.750000   4133.500000    4538.250000
# max    73589.000000  79357.000000  83491.000000  93917.000000  101161.000000
#
#                 2008           2009           2010           2011  \
# count      36.000000      36.000000      36.000000      36.000000
# mean     5921.722222    6166.277778    6642.111111    6756.555556
# std     17667.592536   18395.239144   19824.021874   20152.425372
# ...

# %%
## The number of accidents happening per state from the year 2003 to 2016.
df3['Total Accidents 2003-16'] = df3.iloc[:,1:15].sum(axis=1)
Accidents_2003to16 = df3[['States/Uts','Total Accidents 2003-16']]
print(Accidents_2003to16)
# Out:
#                    States/Uts  Total Accidents 2003-16
# 0              Andhra Pradesh                 152359.0
# 1           Arunachal Pradesh                   1309.0
# 2                       Assam                  25051.0
# 3                       Bihar                  50328.0
# 4                Chhattisgarh                  37655.0
# 5                         Goa                   3932.0
# 6                     Gujarat                  86631.0
# 7                     Haryana                  54286.0
# 8            Himachal Pradesh                   9790.0
# 9             Jammu & Kashmir                  10469.0
# 10                  Jharkhand                  29837.0
# 11                  Karnataka                 111292.0
# 12                     Kerala                  49824.0
# 13             Madhya Pradesh                  88699.0
# 14                Maharashtra                 147503.0
# 15                    Manipur                   1642.0
# ...

# %%
df4 = pd.read_csv('/content/laneAccidents.csv')
# Q-7 Numberof ACCIDENTSfor1,2,3,4 LANE per 1L population of resp. state.

df4.describe()
# Out:
#        Single Lane - Accident - 2014  \
# count                      36.000000
# mean                    11540.277778
# std                     34523.823440
# min                         1.000000
# 25%                       307.250000
# 50%                      3330.500000
# 75%                      8129.250000
# max                    207725.000000
#
#        Single Lane - Accident - 2014 per 1L people  \
# count                                    36.000000
# mean                                     21.431678
# std                                      28.170904
# min                                       1.551037
# 25%                                       8.160290
# 50%                                      15.774448
# 75%                                      22.982260
# max                                     172.980607
#
#        Single Lane - Killed - 2014  Single Lane - Killed - 2014 per 1L people  \
# ...

# %%
# SINGLE LANE
State_UT = df4.groupby('State/UT')['Single Lane - Accident - 2014 per 1L people'].sum()
print(State_UT)
Single_Lane_Accident_2014= df4['Single Lane - Accident - 2014'].sum()
population = df4['Population'].sum()
accidents_number_per_lakh = (Single_Lane_Accident_2014/ population) * 100000

print("Number of Accidents on Single Lane per 1 Lakh Population:", accidents_number_per_lakh)
# Out:
# State/UT
# Andaman & Nicobar Islands     26.012859
# Andhra Pradesh                16.473750
# Arunachal Pradesh              6.504173
# Assam                         12.459312
# Bihar                          3.584073
# Chandigarh                    12.411767
# Chhattisgarh                  31.164370
# Dadra & Nagar Haveli           6.109820
# Daman & Diu                    5.344362
# Delhi                          0.000000
# Goa                          172.980607
# Gujarat                       18.163560
# Haryana                       16.133192
# Himachal Pradesh              17.233337
# Jammu & Kashmir               29.988912
# Jharkhand                      7.423882
# Karnataka                     43.320847
# Kerala                        21.972061
# Lakshadweep                    1.551037
# Madhya Pradesh                39.243084
# Maharashtra                   20.676430
# Manipur                       14.811993
# Meghalaya                     10.381244
# ...

# %%
# DOUBLE LANE
State_UT = df4.groupby('State/UT')['Two Lanes - Accident - 2014 per 1L people'].sum()
print(State_UT)
Two_Lanes_Accident_2014_Lane_Accident_2014= df4['Two Lanes - Accident - 2014'].sum()
population = df4['Population'].sum()
accidents_number_per_lakh = (Two_Lanes_Accident_2014_Lane_Accident_2014/ population) * 100000

print("Number of Accidents on TWO Lane per 1 Lakh Population:", accidents_number_per_lakh)
# Out:
# State/UT
# Andaman & Nicobar Islands     30.216958
# Andhra Pradesh                19.704009
# Arunachal Pradesh              8.310888
# Assam                          7.793479
# Bihar                          3.992336
# Chandigarh                     7.105974
# Chhattisgarh                  18.383103
# Dadra & Nagar Haveli          19.202290
# Daman & Diu                   10.688724
# Delhi                          0.000000
# Goa                          116.965880
# Gujarat                       12.367700
# Haryana                       13.490346
# Himachal Pradesh              27.314038
# Jammu & Kashmir               15.429020
# Jharkhand                      6.841854
# Karnataka                     22.676050
# Kerala                        82.053972
# Lakshadweep                    0.000000
# Madhya Pradesh                30.055017
# Maharashtra                   20.323146
# Manipur                       10.925158
# Meghalaya                      7.887049
# ...

# %%
# THREE LANE
print("Number of Accidents on THREE Lane per 1 Lakh Population:", accidents_number_per_lakh)
State_UT = df4.groupby('State/UT')['3 Lanes or more w.o Median - Accident - 2014 per 1L people'].sum()
print(State_UT)
_3_Lanes_more_w_o_Median_Accident_2014= df4['3 Lanes or more w.o Median - Accident - 2014'].sum()
population = df4['Population'].sum()
accidents_number_per_lakh = (_3_Lanes_more_w_o_Median_Accident_2014/ population) * 100000
# Out:
# Number of Accidents on THREE Lane per 1 Lakh Population: 1.8472251101745945
# State/UT
# Andaman & Nicobar Islands    0.262756
# Andhra Pradesh               2.266715
# Arunachal Pradesh            0.000000
# Assam                        0.179455
# Bihar                        0.726229
# Chandigarh                   5.590033
# Chhattisgarh                 0.000000
# Dadra & Nagar Haveli         0.000000
# Daman & Diu                  0.000000
# Delhi                        0.000000
# Goa                          0.000000
# Gujarat                      1.062216
# Haryana                      2.847962
# Himachal Pradesh             0.000000
# Jammu & Kashmir              0.893049
# Jharkhand                    0.097005
# Karnataka                    2.298049
# Kerala                       2.640239
# Lakshadweep                  0.000000
# Madhya Pradesh               0.319441
# Maharashtra                  5.968445
# Manipur                      0.210099
# ...

# %%
#FOUR LANE
print("Number of Accidents on FOUR Lane per 1 Lakh Population:", accidents_number_per_lakh)
State_UT = df4.groupby('State/UT')['4 Lanes with Median - Accident - 2014 per 1L people'].sum()
print(State_UT)
_4_Lanes_with_Median_Killed_2014= df4['4 Lanes with Median - Accident - 2014'].sum()
population = df4['Population'].sum()
accidents_number_per_lakh = (_4_Lanes_with_Median_Killed_2014/ population) * 100000
# Out:
# Number of Accidents on FOUR Lane per 1 Lakh Population: 1.8472251101745945
# State/UT
# Andaman & Nicobar Islands     0.788268
# Andhra Pradesh                8.187267
# Arunachal Pradesh             0.000000
# Assam                         2.461099
# Bihar                         0.877046
# Chandigarh                    9.853617
# Chhattisgarh                  4.556629
# Dadra & Nagar Haveli          0.000000
# Daman & Diu                   0.000000
# Delhi                         0.000000
# Goa                           0.000000
# Gujarat                       7.639020
# Haryana                       9.640470
# Himachal Pradesh              0.000000
# Jammu & Kashmir               0.422604
# Jharkhand                     1.355033
# Karnataka                     3.253933
# Kerala                        1.942761
# Lakshadweep                   0.000000
# Madhya Pradesh                4.008162
# Maharashtra                   7.872794
# Manipur                       0.070033
# ...

# %%
# Q-8 Number of people INJURED for 1,2,3,4 type of lane per 1L population of resp. State.
# SINGLE LANE INJURED

State_UT = df4.groupby('State/UT')['Single Lane - Injured - 2014 per 1L people'].sum()
print(State_UT)
Single_Lane_Injured_2014 = df4['Single Lane - Injured - 2014'].sum()
population = df4['Population'].sum()
Injured_number_per_lakh = (Single_Lane_Injured_2014/ population) * 100000
print("Number of People Injured on Single Lane per 1 Lakh Population:", Injured_number_per_lakh)
# Out:
# State/UT
# Andaman & Nicobar Islands    38.887911
# Andhra Pradesh               25.836350
# Arunachal Pradesh            10.984826
# Assam                        10.238555
# Bihar                         2.377534
# Chandigarh                   13.264484
# Chhattisgarh                 30.385359
# Dadra & Nagar Haveli          8.146426
# Daman & Diu                   4.522152
# Delhi                         0.000000
# Goa                          74.800572
# Gujarat                      17.658925
# Haryana                      13.746742
# Himachal Pradesh             33.825705
# Jammu & Kashmir              32.923216
# Jharkhand                     6.074912
# Karnataka                    58.200879
# Kerala                       23.648403
# Lakshadweep                   1.551037
# Madhya Pradesh               40.317068
# Maharashtra                  15.237465
# Manipur                      26.682597
# Meghalaya                     4.246873
# Mizoram                      11.301433
# ...

# %%
# DOUBLE LANE INJURED

State_UT = df4.groupby('State/UT')['Two Lanes - Injured - 2014 per 1L people'].sum()
print(State_UT)
Two_Lane_Injured_2014 = df4['Two Lanes - Injured - 2014'].sum()
population = df4['Population'].sum()
Injured_number_per_lakh = (Two_Lane_Injured_2014/ population) * 100000
print("Number of People Injured on Two Lane per 1 Lakh Population:", Injured_number_per_lakh)
# Out:
# State/UT
# Andaman & Nicobar Islands    33.895544
# Andhra Pradesh               19.312868
# Arunachal Pradesh            11.273900
# Assam                         8.043434
# Bihar                         2.970237
# Chandigarh                    7.011227
# Chhattisgarh                 18.246091
# Dadra & Nagar Haveli         19.784178
# Daman & Diu                  15.621981
# Delhi                         0.000000
# Goa                          54.026444
# Gujarat                      11.748902
# Haryana                      11.340569
# Himachal Pradesh             47.402603
# Jammu & Kashmir              29.135731
# Jharkhand                     5.741458
# Karnataka                    30.400049
# Kerala                       94.285286
# Lakshadweep                   0.000000
# Madhya Pradesh               30.981672
# Maharashtra                  13.104416
# Manipur                      18.208596
# Meghalaya                     6.235488
# Mizoram                      10.025465
# ...

# %%
# THREE LANE INJURED

State_UT = df4.groupby('State/UT')['3 Lanes or more w.o Median - Injured - 2014 per 1L people'].sum()
print(State_UT)
_3_Lanes_more_w_o_Median_Accident_2014 = df4['3 Lanes or more w.o Median - Injured - 2014'].sum()
population = df4['Population'].sum()
Injured_number_per_lakh = (_3_Lanes_more_w_o_Median_Accident_2014/ population) * 100000
print("Number of People Injured on THREE Lane per 1 Lakh Population:", Injured_number_per_lakh)
# Out:
# State/UT
# Andaman & Nicobar Islands    0.262756
# Andhra Pradesh               2.287703
# Arunachal Pradesh            0.000000
# Assam                        0.134591
# Bihar                        0.465901
# Chandigarh                   3.316121
# Chhattisgarh                 0.000000
# Dadra & Nagar Haveli         0.000000
# Daman & Diu                  0.000000
# Delhi                        0.000000
# Goa                          0.000000
# Gujarat                      0.870289
# Haryana                      1.538373
# Himachal Pradesh             0.000000
# Jammu & Kashmir              1.610678
# Jharkhand                    0.072753
# Karnataka                    1.468198
# Kerala                       3.017417
# Lakshadweep                  0.000000
# Madhya Pradesh               0.289149
# Maharashtra                  2.621595
# Manipur                      0.385182
# Meghalaya                    0.000000
# Mizoram                      0.000000
# ...

# %%
#FOUR LANE INURED

print("Number of INJURED on FOUR Lane per 1 Lakh Population:", Injured_number_per_lakh)
State_UT = df4.groupby('State/UT')['4 Lanes with Median - Injured - 2014 per 1L people'].sum()
print(State_UT)
_4_Lanes_with_Median_Injured_2014= df4['4 Lanes with Median - Injured - 2014'].sum()
population = df4['Population'].sum()
Injured_number_per_lakh = (_4_Lanes_with_Median_Injured_2014/ population) * 100000
# Out:
# Number of INJURED on FOUR Lane per 1 Lakh Population: 1.1881271307261216
# State/UT
# Andaman & Nicobar Islands     1.313781
# Andhra Pradesh                9.671698
# Arunachal Pradesh             0.000000
# Assam                         2.409826
# Bihar                         0.564844
# Chandigarh                    8.148183
# Chhattisgarh                  2.873338
# Dadra & Nagar Haveli          0.000000
# Daman & Diu                   0.000000
# Delhi                         0.000000
# Goa                           0.000000
# Gujarat                       6.937494
# Haryana                       8.654333
# Himachal Pradesh              0.000000
# Jammu & Kashmir               0.462472
# Jharkhand                     1.315625
# Karnataka                     2.951127
# Kerala                        2.068487
# Lakshadweep                   0.000000
# Madhya Pradesh                4.602983
# Maharashtra                   5.036737
# Manipur                       0.070033
# ...

# %%
# Q-9 Number of people KILLED for 1,2,3,4 LANES per 1L population of resp. States.
# SINGLE LANE KILLED

State_UT = df4.groupby('State/UT')['Single Lane - Killed - 2014 per 1L people'].sum()
print(State_UT)
Single_Lane_killed_2014 = df4['Single Lane - Killed - 2014'].sum()
population = df4['Population'].sum()
killed_number_per_lakh = (Single_Lane_killed_2014/ population) * 100000
print("Number of People killed on Single Lane per 1 Lakh Population:", killed_number_per_lakh)
# Out:
# State/UT
# Andaman & Nicobar Islands     2.102049
# Andhra Pradesh                5.643891
# Arunachal Pradesh             4.336115
# Assam                         3.899944
# Bihar                         1.743525
# Chandigarh                    4.358331
# Chhattisgarh                  8.784430
# Dadra & Nagar Haveli          4.364157
# Daman & Diu                   2.055524
# Delhi                         0.000000
# Goa                          12.820996
# Gujarat                       5.130734
# Haryana                       6.173214
# Himachal Pradesh              7.691633
# Jammu & Kashmir               4.369562
# Jharkhand                     3.185994
# Karnataka                     9.499913
# Kerala                        3.403574
# Lakshadweep                   0.000000
# Madhya Pradesh                6.090038
# Maharashtra                   4.727058
# Manipur                       3.116471
# Meghalaya                     2.730132
# Mizoram                       4.101326
# ...

# %%
# DOUBLE LANE KILLED
State_UT = df4.groupby('State/UT')['Two Lanes - Killed - 2014 per 1L people'].sum()
print(State_UT)
Two_Lane_killed_2014 = df4['Two Lanes - Killed - 2014'].sum()
population = df4['Population'].sum()
killed_number_per_lakh = (Two_Lane_killed_2014/ population) * 100000
print("Number of People Killed on Two Lane per 1 Lakh Population:", killed_number_per_lakh)
# Out:
# State/UT
# Andaman & Nicobar Islands     3.941342
# Andhra Pradesh                5.712579
# Arunachal Pradesh             4.263847
# Assam                         3.316715
# Bihar                         2.013459
# Chandigarh                    2.558151
# Chhattisgarh                  5.965896
# Dadra & Nagar Haveli         12.801527
# Daman & Diu                   4.111048
# Delhi                         0.000000
# Goa                           7.061832
# Gujarat                       4.415972
# Haryana                       5.723536
# Himachal Pradesh              9.774784
# Jammu & Kashmir               3.340961
# Jharkhand                     3.577044
# Karnataka                     6.517687
# Kerala                        8.196117
# Lakshadweep                   0.000000
# Madhya Pradesh                4.956847
# Maharashtra                   4.204697
# Manipur                       2.661256
# Meghalaya                     2.022320
# Mizoram                       5.286154
# ...

# %%
# THREE LANE KILLED
State_UT = df4.groupby('State/UT')['3 Lanes or more w.o Median - Killed - 2014 per 1L people'].sum()
print(State_UT)
_3_Lanes_more_w_o_Median_Killed_2014 = df4['3 Lanes or more w.o Median - Killed - 2014'].sum()
population = df4['Population'].sum()
killed_number_per_lakh = (_3_Lanes_more_w_o_Median_Killed_2014/ population) * 100000
print("Number of People Killed on THREE Lane per 1 Lakh Population:",killed_number_per_lakh)
# Out:
# State/UT
# Andaman & Nicobar Islands    0.000000
# Andhra Pradesh               0.755572
# Arunachal Pradesh            0.000000
# Assam                        0.080114
# Bihar                        0.374642
# Chandigarh                   1.894926
# Chhattisgarh                 0.000000
# Dadra & Nagar Haveli         0.000000
# Daman & Diu                  0.000000
# Delhi                        0.000000
# Goa                          0.000000
# Gujarat                      0.410326
# Haryana                      1.341146
# Himachal Pradesh             0.000000
# Jammu & Kashmir              0.167447
# Jharkhand                    0.060628
# Karnataka                    0.626889
# Kerala                       0.245464
# Lakshadweep                  0.000000
# Madhya Pradesh               0.049568
# Maharashtra                  0.690549
# Manipur                      0.035017
# Meghalaya                    0.000000
# Mizoram                      0.000000
# ...

# %%
# FOUR LANE KILLED

print("Number of Killed on FOUR Lane per 1 Lakh Population:", killed_number_per_lakh)
State_UT = df4.groupby('State/UT')['4 Lanes with Median - Killed - 2014 per 1L people'].sum()
print(State_UT)
_4_Lanes_with_Median_Killed_2014= df4['4 Lanes with Median - Killed - 2014'].sum()
population = df4['Population'].sum()
Killed_number_per_lakh = (_4_Lanes_with_Median_Killed_2014/ population) * 100000
# Out:
# Number of Killed on FOUR Lane per 1 Lakh Population: 0.448014852588393
# State/UT
# Andaman & Nicobar Islands    0.000000
# Andhra Pradesh               2.976494
# Arunachal Pradesh            0.000000
# Assam                        0.785116
# Bihar                        0.587899
# Chandigarh                   3.600360
# Chhattisgarh                 0.994316
# Dadra & Nagar Haveli         0.000000
# Daman & Diu                  0.000000
# Delhi                        0.000000
# Goa                          0.000000
# Gujarat                      3.204848
# Haryana                      4.445503
# Himachal Pradesh             0.000000
# Jammu & Kashmir              0.031895
# Jharkhand                    1.142835
# Karnataka                    0.463211
# Kerala                       0.275399
# Lakshadweep                  0.000000
# Madhya Pradesh               0.702220
# Maharashtra                  1.770867
# Manipur                      0.070033
# ...

# %%
df4 = pd.read_csv('/content/laneAccidents.csv')

# %%
# Q-10 Number of Accidents, people KILLED, INJURED on SINGLE LANE per 1L
# population.

df4.describe()
# Out:
#        Single Lane - Accident - 2014  \
# count                      36.000000
# mean                    11540.277778
# std                     34523.823440
# min                         1.000000
# 25%                       307.250000
# 50%                      3330.500000
# 75%                      8129.250000
# max                    207725.000000
#
#        Single Lane - Accident - 2014 per 1L people  \
# count                                    36.000000
# mean                                     21.431678
# std                                      28.170904
# min                                       1.551037
# 25%                                       8.160290
# 50%                                      15.774448
# 75%                                      22.982260
# max                                     172.980607
#
#        Single Lane - Killed - 2014  Single Lane - Killed - 2014 per 1L people  \
# ...

# %%
#Q- 10 Number of Accidents, people KILLED, INJURED on SINGLE LANE per 1L
#  population.

Single_Lane_Accident_2014= df4['Single Lane - Accident - 2014'].sum()
Single_Lane_Killed_2014=df4['Single Lane - Killed - 2014'].sum()
Single_Lane_Injured_2014 = df4['Single Lane - Injured - 2014'].sum()
population = df4['Population'].sum()

accidents_number_per_lakh = (Single_Lane_Accident_2014/ population) * 100000
killed_number_per_lakh = (Single_Lane_Killed_2014/ population) * 100000
injured_number_per_lakh = (Single_Lane_Injured_2014/ population) * 100000

print("Number of Accidents on Single Lane per 1 Lakh Population:", accidents_number_per_lakh)
print("Number of People Killed on Single Lane per 1 Lakh Population:",killed_number_per_lakh)
print("Number of People Injured on Single Lane per 1 Lakh Population:", injured_number_per_lakh )

# visualization of  Number of Accidents, people KILLED, INJURED on SINGLE LANE per 1L
# population.

plt.figure(figsize=(10, 6))
sns.barplot(x=['Accidents', 'Killed', 'Injured'], y=[accidents_number_per_lakh, killed_number_per_lakh ,injured_number_per_lakh])
plt.title('Accidents, Killed, and Injured per 1L Population')
plt.xlabel('Category')
plt.ylabel('Accidents, Killed, and Injured per 1L Population')
plt.show()
# Out:
# Number of Accidents on Single Lane per 1 Lakh Population: 17.15463322652976
# Number of People Killed on Single Lane per 1 Lakh Population: 4.982750994612586
# Number of People Injured on Single Lane per 1 Lakh Population: 17.949993787871474

# %%
# Q-11 Number of accidents, people INJURED, KILLED on DOUBLE LANE per 1L
# population.

Two_Lanes_Accident_2014 = df4['Two Lanes - Accident - 2014'].sum()
Two_Lanes_Injured_2014= df4['Two Lanes - Injured - 2014'].sum()
Two_Lanes_Killed_2014= df4['Two Lanes - Killed - 2014'].sum()
population = df4['Population'].sum()

accidents_per_lakh = (Two_Lanes_Accident_2014 / population) * 100000
injured_per_lakh = (Two_Lanes_Injured_2014 / population) * 100000
killed_per_lakh= (Two_Lanes_Killed_2014 / population) * 100000

print("Number of Accidents on Double Lane 1 Lakh Population:", accidents_per_lakh)
print("Number of People Injured on Double Lane per 1 Lakh Population:", injured_per_lakh)
print("Number of People Killed on Double Lane per 1 Lakh Population:",killed_per_lakh)

# visualization of  Number of Accidents, people Injured, Killed on Double LANE per 1L
# population.



plt.figure(figsize=(8, 5))
sns.barplot(x=['Accidents', 'Injured','Killed'], y=[accidents_per_lakh, injured_per_lakh, killed_per_lakh], palette='Spectral')
plt.title('Acccidents,INJURED, KILLED on DOUBLE LANE per 1L population)', fontsize=14)
plt.xlabel('Category')
plt.ylabel('Acccidents,INJURED, KILLED on DOUBLE LANE per 1L population')
plt.show()
# Out:
# Number of Accidents on Double Lane 1 Lakh Population: 15.954118588358796
# Number of People Injured on Double Lane per 1 Lakh Population: 16.374055090738885
# Number of People Killed on Double Lane per 1 Lakh Population: 4.379644548814793

# %%
# Q-12 Number of accidents, people INJURED, KILLED on THREE LANE per 1L
# population.

_3_Lanes_more_w_o_Median_Accident_2014 = df4['3 Lanes or more w.o Median - Accident - 2014'].sum()
_3_Lanes_more_w_o_Median_Injured_2014 = df4['3 Lanes or more w.o Median - Injured - 2014'].sum()
_3_Lanes_more_w_o_Median_Killed_2014 = df4['3 Lanes or more w.o Median - Killed - 2014'].sum()
population = df4['Population'].sum()

accidents_per_lakh = (_3_Lanes_more_w_o_Median_Accident_2014/ population) * 100000
injured_per_lakh = (_3_Lanes_more_w_o_Median_Injured_2014 / population) * 100000
killed_per_lakh = (_3_Lanes_more_w_o_Median_Killed_2014  / population) * 100000

print("Number of Accidents on Three Lane 1 Lakh Population:", accidents_per_lakh)
print("Number of People Injured on Three Lane per 1 Lakh Population:", injured_per_lakh)
print("Number of People Killed on Three Lane per 1 Lakh Population:", killed_per_lakh)

# visualization of  Number of Accidents, people KILLED, INJURED on THREE LANE per 1L
# population.

plt.figure(figsize=(10, 6))
sns.barplot(x=['Accidents', 'Injured', 'Killed'], y=[accidents_per_lakh, injured_per_lakh, killed_per_lakh])
plt.title('Acccidents,INJURED, KILLED on THREE  LANE per 1L population')
plt.xlabel('Category')
plt.ylabel('Acccidents,INJURED, KILLED on THREE LANE per 1L population')
plt.show()
# Out:
# Number of Accidents on Three Lane 1 Lakh Population: 1.8472251101745945
# Number of People Injured on Three Lane per 1 Lakh Population: 1.1881271307261216
# Number of People Killed on Three Lane per 1 Lakh Population: 0.448014852588393

# %%
# Q-13 Number of accidents, people INJURED, KILLED on FOUR LANE per 1L population.

_4_Lanes_with_Median_Accident_2014 = df4['4 Lanes with Median - Accident - 2014'].sum()
_4_Lanes_with_Median_Injured_2014 = df4['4 Lanes with Median - Injured - 2014'].sum()
_4_Lanes_with_Median_Killed_2014 = df4['4 Lanes with Median - Killed - 2014'].sum()
population = df4['Population'].sum()

accidents_per_lakh = (_4_Lanes_with_Median_Accident_2014/ population) * 100000
injured_per_lakh = (_4_Lanes_with_Median_Injured_2014 / population) * 100000
killed_per_lakh = (_4_Lanes_with_Median_Killed_2014 / population) * 100000

print("Number of Accidents on Three Lane 1 Lakh Population:", accidents_per_lakh)
print("Number of People Injured on Three Lane per 1 Lakh Population:", injured_per_lakh)
print("Number of People Killed on Three Lane per 1 Lakh Population:", killed_per_lakh)

# visualization of  Number of Accidents, people KILLED, INJURED on FOUR LANE per 1L
# population.

plt.figure(figsize=(10, 6))
sns.barplot(x=['Accidents', 'Injured', 'Killed'], y=[accidents_per_lakh, injured_per_lakh, killed_per_lakh], palette='Spectral')
plt.title('Acccidents,INJURED, KILLED on FOUR LANE per 1L population')
plt.xlabel('Category')
plt.ylabel('Acccidents,INJURED, KILLED on FOUR LANE per 1L population')
plt.show()
# Out:
# Number of Accidents on Three Lane 1 Lakh Population: 4.746892852862826
# Number of People Injured on Three Lane per 1 Lakh Population: 4.556538155127113
# Number of People Killed on Three Lane per 1 Lakh Population: 1.5860964532373598

# %%
data = np.array(df4['4 Lanes with Median - Accident - 2014'])

median = np.median(data)
# Without Median Data
data_without_median = data[data != median]

print("Median:", median)
print("Data without median:", data_without_median)
# Out:
# Median: nan
# Data without median: [4.2910e+03 0.0000e+00 7.6800e+02 9.1300e+02 1.1640e+03 0.0000e+00
#  4.6170e+03 2.4440e+03 0.0000e+00 5.3000e+01 4.4700e+02 1.9880e+03
#  6.4900e+02 2.9110e+03 8.8470e+03 2.0000e+00 0.0000e+00 0.0000e+00
#  0.0000e+00 1.0720e+03 8.2300e+02 4.3930e+03 0.0000e+00 1.3078e+04
#  3.6860e+03 0.0000e+00 0.0000e+00 4.4710e+03 7.3700e+02 3.0000e+00
#  1.0400e+02 0.0000e+00 0.0000e+00        nan 0.0000e+00 1.9000e+01
#  5.7480e+04]

# %% [markdown]
# ** Q-14 Total Number of INJURED, KILLED, ROAD ACCIDENTS irrespective of
#   lanes per 1L population of resp. State**
#  **bold text:**

# %%
total_injured = df4['Single Lane - Injured - 2014'].sum() + df4['Two Lanes - Injured - 2014'].sum() + df4['3 Lanes or more w.o Median - Injured - 2014'].sum() \
+ df4['4 Lanes with Median - Injured - 2014'].sum()
total_killed = df4['Single Lane - Killed - 2014'].sum() + df4['Two Lanes - Killed - 2014'].sum() + df4['3 Lanes or more w.o Median - Killed - 2014'].sum() \
+ df4['4 Lanes with Median - Killed - 2014'].sum()
+ df4['3 Lanes or more w.o Median - Killed - 2014'].sum() + df4['4 Lanes with Median - Killed - 2014'].sum()
total_accidents = df4['Single Lane - Accident - 2014'].sum() + df4['Two Lanes - Accident - 2014'].sum() \
 + df4['3 Lanes or more w.o Median - Accident - 2014'].sum() + df4['4 Lanes with Median - Accident - 2014'].sum()
total_population = df4['Population'].sum()

total_injured_per_lakh = (total_injured / total_population) * 100000
total_killed_per_lakh = (total_killed / total_population) * 100000
total_accidents_per_lakh = (total_accidents / total_population) * 100000

print("Total Injured per 1 Lakh Population:", total_injured_per_lakh)
print("Total Killed per 1 Lakh Population:", total_killed_per_lakh)
print("Total Accidents per 1 Lakh Population:", total_accidents_per_lakh)
# Out:
# Total Injured per 1 Lakh Population: 40.06871416446359
# Total Killed per 1 Lakh Population: 11.39650684925313
# Total Accidents per 1 Lakh Population: 39.702869777925976

# %%
df5 = pd.read_csv('/content/reasonOfAccident.csv')

# %% [markdown]
#  **Q-15 Number of people KILLED for each different REASON per 1L population of that state**

# %%
State_UT = df5.groupby('States/UTs')['Fault of Driver-Number of Persons-Killed - 2014 per 1L people'].sum()
print(State_UT)
Fault_of_Driver_Number_of_Persons_Killed_2014= df5['Fault of Driver-Number of Persons-Killed - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Killed_number_per_lakh = (Fault_of_Driver_Number_of_Persons_Killed_2014/ population) * 100000
print(Killed_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.     6.043392
# Andhra Pradesh           12.865705
# Arunachal Pradesh         1.373103
# Assam                     7.783865
# Bihar                     2.541800
# Chandigarh               12.411767
# Chhattisgarh              9.622161
# Dadra & Nagar Haveli     17.165684
# Daman & Diu               6.166571
# Delhi                     5.098898
# Goa                      16.934685
# Gujarat                  10.977885
# Haryana                  12.567323
# Himachal Pradesh         16.723475
# Jammu & Kashmir           4.473220
# Jharkhand                 4.104506
# Karnataka                13.925785
# Kerala                   12.120555
# Lakshadweep               0.000000
# Madhya Pradesh            9.280320
# Maharashtra               9.889269
# Manipur                   0.000000
# Meghalaya                 0.404464
# Mizoram                   8.567215
# Nagaland                  3.133684
# Odisha                    8.993616
# ...

# %%
#Fault of Driver of other vehicles-Number of Persons-Killed - 2014

State_UT = df5.groupby('States/UTs')['Fault of Driver of other vehicles-Number of Persons-Killed - 2014 per 1L people'].sum()
print(State_UT)
Fault_of_Driver_Number_of_other_vehicles_Killed_2014= df5['Fault of Driver of other vehicles-Number of Persons-Killed - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Killed_number_per_lakh = (Fault_of_Driver_Number_of_other_vehicles_Killed_2014/ population) * 100000
print(Killed_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.143101
# Arunachal Pradesh        1.011760
# Assam                    0.003205
# Bihar                    0.243997
# Chandigarh               0.000000
# Chhattisgarh             0.990401
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.077437
# Goa                      0.000000
# Gujarat                  0.281272
# Haryana                  0.828355
# Himachal Pradesh         0.043702
# Jammu & Kashmir          0.494367
# Jharkhand                0.633561
# Karnataka                1.060638
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.476408
# Maharashtra              0.472528
# Manipur                  0.000000
# Meghalaya                0.505580
# Mizoram                  0.820265
# Nagaland                 0.657063
# Odisha                   0.038119
# Puducherry               0.000000
# ...

# %%
#  Fault of Pedestrian-Number of Persons-Killed - 2014
State_UT = df5.groupby('States/UTs')['Fault of Pedestrian-Number of Persons-Killed - 2014 per 1L people'].sum()
print(State_UT)
Fault_of_Pedestrain_Number_of_Person_killed_2014= df5['Fault of Pedestrian-Number of Persons-Killed - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Killed_number_per_lakh = (Fault_of_Pedestrain_Number_of_Person_killed_2014/ population) * 100000
print(Killed_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.198433
# Arunachal Pradesh        0.000000
# Assam                    0.169841
# Bihar                    0.138329
# Chandigarh               0.000000
# Chhattisgarh             0.160500
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      1.988283
# Gujarat                  0.670089
# Haryana                  0.552236
# Himachal Pradesh         0.000000
# Jammu & Kashmir          0.279078
# Jharkhand                0.585059
# Karnataka                0.126033
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.013769
# Maharashtra              0.098777
# Manipur                  0.000000
# Meghalaya                0.370759
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.109591
# Puducherry               0.000000
# ...

# %%
# Defect in Condition of Motor Vehicle-Number of Persons-Killed - 2014

State_UT = df5.groupby('States/UTs')['Defect in Condition of Motor Vehicle-Number of Persons-Killed - 2014 per 1L people'].sum()
print(State_UT)
defect_in_condition_of_motor_vehicle_Number_of_Person_killed_2014 = df5['Defect in Condition of Motor Vehicle-Number of Persons-Killed - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Killed_number_per_lakh = (defect_in_condition_of_motor_vehicle_Number_of_Person_killed_2014/ population) * 100000
print(Killed_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.049608
# Arunachal Pradesh        0.578149
# Assam                    0.000000
# Bihar                    0.290107
# Chandigarh               0.000000
# Chhattisgarh             0.896450
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.041697
# Goa                      0.000000
# Gujarat                  0.099273
# Haryana                  0.422066
# Himachal Pradesh         0.538997
# Jammu & Kashmir          0.302999
# Jharkhand                0.472897
# Karnataka                0.184957
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.509454
# Maharashtra              0.087209
# Manipur                  0.945446
# Meghalaya                0.741517
# Mizoram                  0.000000
# Nagaland                 0.303260
# Odisha                   0.021442
# Puducherry               0.000000
# ...

# %%
# Defect in Road Condition-Number of Persons-Killed - 2014

State_UT = df5.groupby('States/UTs')['Defect in Road Condition-Number of Persons-Killed - 2014 per 1L people'].sum()
print(State_UT)
defect_in_Road_condition_Number_of_Person_killed_2014 = df5['Defect in Road Condition-Number of Persons-Killed - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Killed_number_per_lakh = (defect_in_Road_condition_Number_of_Person_killed_2014/ population) * 100000
print(Killed_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.366338
# Arunachal Pradesh        0.650417
# Assam                    0.000000
# Bihar                    0.242076
# Chandigarh               0.000000
# Chhattisgarh             0.555877
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.000000
# Gujarat                  0.052945
# Haryana                  0.291896
# Himachal Pradesh         0.160242
# Jammu & Kashmir          0.087710
# Jharkhand                0.415301
# Karnataka                0.070382
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.309803
# Maharashtra              0.070301
# Manipur                  0.350165
# Meghalaya                0.404464
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.021442
# Puducherry               0.000000
# ...

# %%
# Weather Condition-Number of Persons-Killed - 2014

State_UT = df5.groupby('States/UTs')['Weather Condition-Number of Persons-Killed - 2014 per 1L people'].sum()
print(State_UT)
Weather_condition_Number_of_Person_killed_2014 = df5['Weather Condition-Number of Persons-Killed - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Killed_number_per_lakh = (Weather_condition_Number_of_Person_killed_2014/ population) * 100000
print(Killed_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.036252
# Arunachal Pradesh        0.939492
# Assam                    0.000000
# Bihar                    0.201730
# Chandigarh               0.000000
# Chhattisgarh             0.234878
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.000000
# Gujarat                  0.071145
# Haryana                  0.295841
# Himachal Pradesh         0.000000
# Jammu & Kashmir          0.015947
# Jharkhand                0.284951
# Karnataka                0.330631
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.114283
# Maharashtra              0.036485
# Manipur                  0.525248
# Meghalaya                0.303348
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.026207
# Puducherry               0.000000
# ...

# %%
# Fault of Passenger-Number of Persons-Killed - 2014

State_UT = df5.groupby('States/UTs')['Fault of Passenger-Number of Persons-Killed - 2014 per 1L people'].sum()
print(State_UT)
Fault_of_Passenger_Number_of_Person_killed_2014 = df5['Fault of Passenger-Number of Persons-Killed - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Killed_number_per_lakh = (Fault_of_Passenger_Number_of_Person_killed_2014/ population) * 100000
print(Killed_number_per_lakh)


# VISUALIZATION

plt.figure(figsize=(10, 6))
plt.plot(State_UT.index, State_UT.values)
plt.xlabel('States/UTs')
plt.ylabel('Passenger-Number of Persons-Killed - 2014 per 1L people')
plt.title('Fault of Passenger-Number of Persons-Killed - 2014 per 1L people')
plt.xticks(rotation=90)
plt.show()
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.034344
# Arunachal Pradesh        0.289074
# Assam                    0.000000
# Bihar                    0.146975
# Chandigarh               0.000000
# Chhattisgarh             0.254451
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.000000
# Gujarat                  0.071145
# Haryana                  0.382621
# Himachal Pradesh         0.000000
# Jammu & Kashmir          0.000000
# Jharkhand                0.081848
# Karnataka                0.032736
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.111529
# Maharashtra              0.025807
# Manipur                  0.210099
# Meghalaya                0.404464
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.009530
# Puducherry               0.000000
# ...

# %%
# Poor light-Number of Persons-Killed - 2014
State_UT = df5.groupby('States/UTs')['Poor light-Number of Persons-Killed - 2014 per 1L people'].sum()
print(State_UT)
Poor_Light_Number_of_Person_killed_2014 = df5['Poor light-Number of Persons-Killed - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Killed_number_per_lakh = (Poor_Light_Number_of_Person_killed_2014/ population) * 100000
print(Killed_number_per_lakh)

# VISUALIZATION
plt.figure(figsize=(10, 6))
plt.plot(State_UT.index, State_UT.values)
plt.xlabel('States/UTs')
plt.ylabel('Number of Persons-Killed - 2014 per 1L people')
plt.title('Poor light-Number of Persons-Killed - 2014 per 1L people')
plt.xticks(rotation=90)
plt.show()
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.145009
# Arunachal Pradesh        1.517640
# Assam                    0.000000
# Bihar                    0.161384
# Chandigarh               0.000000
# Chhattisgarh             0.352317
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.053610
# Goa                      0.000000
# Gujarat                  0.072800
# Haryana                  0.311619
# Himachal Pradesh         0.000000
# Jammu & Kashmir          0.000000
# Jharkhand                0.148538
# Karnataka                0.085113
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.075730
# Maharashtra              0.042714
# Manipur                  0.070033
# Meghalaya                0.303348
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.007147
# Puducherry               0.000000
# ...

# %%
# Falling of boulders-Number of Persons-Killed - 2014

State_UT = df5.groupby('States/UTs')['Falling of boulders-Number of Persons-Killed - 2014 per 1L people'].sum()
print(State_UT)
Falling_of_boulders_number_of_Person_killed_2014 = df5['Falling of boulders-Number of Persons-Killed - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Killed_number_per_lakh = (Falling_of_boulders_number_of_Person_killed_2014/ population) * 100000
print(Killed_number_per_lakh)

# VISUALIZATION

plt.subplots(figsize=(10, 6))
sns.barplot(x='States/UTs', y='Falling of boulders-Number of Persons-Killed - 2014 per 1L people', data=df5)
plt.xticks(rotation=90)
plt.xlabel('States/UTs')
plt.title('Falling of boulders-Number of Persons-Killed - 2014 per 1L people')
plt.show()
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.001908
# Arunachal Pradesh        0.000000
# Assam                    0.000000
# Bihar                    0.042267
# Chandigarh               0.000000
# Chhattisgarh             0.027402
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.000000
# Gujarat                  0.003309
# Haryana                  0.315564
# Himachal Pradesh         0.000000
# Jammu & Kashmir          0.000000
# Jharkhand                0.045471
# Karnataka                0.021278
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.002754
# Maharashtra              0.000000
# Manipur                  0.000000
# Meghalaya                0.202232
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.009530
# Puducherry               0.000000
# ...

# %%
# Other causes/causes not known-Number of Persons-Killed - 2014

State_UT = df5.groupby('States/UTs')['Other causes/causes not known-Number of Persons-Killed - 2014 per 1L people'].sum()
print(State_UT)
Other_Causes_not__known_number_of_Person_killed_2014 = df5['Other causes/causes not known-Number of Persons-Killed - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Killed_number_per_lakh = (Other_Causes_not__known_number_of_Person_killed_2014/ population) * 100000
print(Killed_number_per_lakh)

# VISUALIZATION

fig, ax = plt.subplots(figsize=(10, 6))
sns.barplot(x='States/UTs', y='Other causes/causes not known-Number of Persons-Killed - 2014 per 1L people', data=df5)
plt.xticks(rotation=90)
plt.xlabel('States/UTs')
plt.title('Other causes/causes not known Persons-Killed - 2014 per 1L people')
plt.show()
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           1.039865
# Arunachal Pradesh        1.589909
# Assam                    0.032046
# Bihar                    0.507207
# Chandigarh               0.000000
# Chhattisgarh             2.172620
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    4.681932
# Goa                      0.411369
# Gujarat                  0.620453
# Haryana                  1.128140
# Himachal Pradesh         0.000000
# Jammu & Kashmir          1.562836
# Jharkhand                1.045831
# Karnataka                1.054091
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.824764
# Maharashtra              0.612239
# Manipur                  3.781785
# Meghalaya                1.044866
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.042883
# Puducherry               0.000000
# ...

# %% [markdown]
# # **Q- 16 Number of people INJURED for each reason per 1L people of that state.**

# %%
## Fault of Driver-Number of Persons-Injured - 2014.

State_UT = df5.groupby('States/UTs')['Fault of Driver-Number of Persons-Injured - 2014 per 1L people'].sum()
print(State_UT)
Fault_of_Driver_Number_of_Person_Injured_2014 = df5['Fault of Driver-Number of Persons-Injured - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Injured_number_per_lakh = (Fault_of_Driver_Number_of_Person_Injured_2014/ population) * 100000
print(Injured_number_per_lakh)

# VISUALIZATION

plt.figure(figsize=(10, 6))
plt.plot(State_UT.index, State_UT.values)
plt.xlabel('States/UTs')
plt.ylabel('Number of Persons-Injured - 2014 per 1L people')
plt.title('Fault of Driver-Number of Persons-Injured - 2014 per 1L people')
plt.xticks(rotation=90)
plt.show()
# Out:
# States/UTs
# Andaman & Nicobar Is.     74.359992
# Andhra Pradesh            50.155834
# Arunachal Pradesh          2.168058
# Assam                     20.127813
# Bihar                      3.241131
# Chandigarh                31.740016
# Chhattisgarh              34.096428
# Dadra & Nagar Haveli      27.930604
# Daman & Diu               20.144133
# Delhi                      0.000000
# Goa                      113.126438
# Gujarat                   30.205316
# Haryana                   30.108717
# Himachal Pradesh          77.586435
# Jammu & Kashmir           32.596297
# Jharkhand                  7.175307
# Karnataka                 74.694784
# Kerala                   123.019592
# Lakshadweep                1.551037
# Madhya Pradesh            60.707610
# Maharashtra               30.517645
# Manipur                    0.000000
# Meghalaya                  0.269643
# Mizoram                   20.233211
# Nagaland                   7.935297
# ...

# %%
# Fault of Driver of other vehicles-Number of Persons-Injured - 2014

State_UT = df5.groupby('States/UTs')['Fault of Driver of other vehicles-Number of Persons-Injured - 2014 per 1L people'].sum()
print(State_UT)
Driver_of_other_vehicles_Number_of_Person_Injured_2014 = df5['Fault of Driver of other vehicles-Number of Persons-Injured - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Injured_number_per_lakh = (Driver_of_other_vehicles_Number_of_Person_Injured_2014/ population) * 100000
print(Injured_number_per_lakh)

# VISUALIZATION
plt.figure(figsize=(10, 6))
plt.plot(State_UT.index, State_UT.values)
plt.xlabel('States/UTs')
plt.ylabel('Number of Persons-Injured - 2014 per 1L people')
plt.title('Fault of Driver of other vehicles-Number of Persons-Injured - 2014 per 1L people')
plt.xticks(rotation=90)
plt.show()
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.810904
# Arunachal Pradesh        3.252087
# Assam                    0.003205
# Bihar                    0.379445
# Chandigarh               0.000000
# Chhattisgarh             2.603229
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.000000
# Gujarat                  0.853744
# Haryana                  0.796798
# Himachal Pradesh         0.437025
# Jammu & Kashmir          7.471314
# Jharkhand                0.682063
# Karnataka                7.347538
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           3.084261
# Maharashtra              1.945284
# Manipur                  0.000000
# Meghalaya                0.572991
# Mizoram                  1.093687
# Nagaland                 2.577708
# Odisha                   0.147710
# Puducherry               0.000000
# ...

# %%
# Fault of Pedestrian-Number of Persons-Injured - 2014

State_UT = df5.groupby('States/UTs')['Fault of Pedestrian-Number of Persons-Injured - 2014 per 1L people'].sum()
print(State_UT)
Fault_of_Pedestrain_Number_of_Person_Injured_2014 = df5['Fault of Pedestrian-Number of Persons-Injured - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Injured_number_per_lakh = (Fault_of_Pedestrain_Number_of_Person_Injured_2014/ population) * 100000
print(Injured_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.305281
# Arunachal Pradesh        0.000000
# Assam                    0.413388
# Bihar                    0.223824
# Chandigarh               0.000000
# Chhattisgarh             0.544134
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      5.896287
# Gujarat                  2.169104
# Haryana                  0.761297
# Himachal Pradesh         0.000000
# Jammu & Kashmir          1.060496
# Jharkhand                0.733597
# Karnataka                1.419095
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.136313
# Maharashtra              0.238489
# Manipur                  0.000000
# Meghalaya                0.606696
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.185828
# Puducherry               0.000000
# ...

# %%
# Defect in Condition of Motor Vehicle-Number of Persons-Injured - 2014

State_UT = df5.groupby('States/UTs')['Defect in Condition of Motor Vehicle-Number of Persons-Injured - 2014 per 1L people'].sum()
print(State_UT)
defect_in_condition_of_motor_vehicle_Number_of_Person_Injured_2014 = df5['Defect in Condition of Motor Vehicle-Number of Persons-Injured - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Injured_number_per_lakh = (defect_in_condition_of_motor_vehicle_Number_of_Person_Injured_2014/ population) * 100000
print(Injured_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.162181
# Arunachal Pradesh        1.589909
# Assam                    0.000000
# Bihar                    0.341020
# Chandigarh               0.000000
# Chhattisgarh             1.914254
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.891299
# Gujarat                  0.271345
# Haryana                  0.378676
# Himachal Pradesh         2.272528
# Jammu & Kashmir          1.538915
# Jharkhand                0.666906
# Karnataka                1.325798
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           2.326964
# Maharashtra              0.404897
# Manipur                  7.738653
# Meghalaya                1.381919
# Mizoram                  0.000000
# Nagaland                 1.111952
# Odisha                   0.083385
# Puducherry               0.000000
# ...

# %%
# Defect in Road Condition-Number of Persons-Injured - 2014

State_UT = df5.groupby('States/UTs')['Defect in Road Condition-Number of Persons-Injured - 2014 per 1L people'].sum()
print(State_UT)
defect_Road_condition_Number_of_Person_Injured_2014 = df5['Defect in Road Condition-Number of Persons-Injured - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Injured_number_per_lakh = (defect_Road_condition_Number_of_Person_Injured_2014/ population) * 100000
print(Injured_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.843340
# Arunachal Pradesh        2.095789
# Assam                    0.000000
# Bihar                    0.270895
# Chandigarh               0.000000
# Chhattisgarh             1.491474
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.000000
# Gujarat                  0.177036
# Haryana                  0.220895
# Himachal Pradesh         0.917752
# Jammu & Kashmir          1.020628
# Jharkhand                0.700252
# Karnataka                0.299532
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           1.840918
# Maharashtra              0.288322
# Manipur                  4.482116
# Meghalaya                0.438169
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.054796
# Puducherry               0.000000
# ...

# %%
# Weather Condition-Number of Persons-Injured - 2014

State_UT = df5.groupby('States/UTs')['Weather Condition-Number of Persons-Injured - 2014 per 1L people'].sum()
print(State_UT)
Weather_condition_Number_of_Person_Injured_2014 = df5['Weather Condition-Number of Persons-Injured - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Injured_number_per_lakh = (Weather_condition_Number_of_Person_Injured_2014/ population) * 100000
print(Injured_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.133561
# Arunachal Pradesh        1.806715
# Assam                    0.000000
# Bihar                    0.293950
# Chandigarh               0.000000
# Chhattisgarh             0.806414
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.000000
# Gujarat                  0.398745
# Haryana                  0.268229
# Himachal Pradesh         0.000000
# Jammu & Kashmir          0.287052
# Jharkhand                0.697220
# Karnataka                0.502494
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.616852
# Maharashtra              0.081869
# Manipur                  4.447099
# Meghalaya                0.471875
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.021442
# Puducherry               0.000000
# ...

# %%
# Fault of Passenger-Number of Persons-Injured - 2014

State_UT = df5.groupby('States/UTs')['Fault of Passenger-Number of Persons-Injured - 2014 per 1L people'].sum()
print(State_UT)
Fault_of_Passenger_Number_of_Person_Injured_2014 = df5['Fault of Passenger-Number of Persons-Injured - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Injured_number_per_lakh = (Fault_of_Passenger_Number_of_Person_Injured_2014/ population) * 100000
print(Injured_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.253765
# Arunachal Pradesh        1.951252
# Assam                    0.000000
# Bihar                    0.298753
# Chandigarh               0.000000
# Chhattisgarh             1.190048
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.000000
# Gujarat                  0.226672
# Haryana                  0.315564
# Himachal Pradesh         0.000000
# Jammu & Kashmir          0.000000
# Jharkhand                0.139444
# Karnataka                0.473032
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.691205
# Maharashtra              0.061402
# Manipur                  3.501653
# Meghalaya                0.539285
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.016677
# Puducherry               0.000000
# ...

# %%
# Poor light-Number of Persons-Injured - 2014

State_UT = df5.groupby('States/UTs')['Poor light-Number of Persons-Injured - 2014 per 1L people'].sum()
print(State_UT)
Poor_Light_Number_of_Person_Injured_2014 = df5['Poor light-Number of Persons-Injured - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])

Injured_number_per_lakh = (Poor_Light_Number_of_Person_Injured_2014/ population) * 100000
print(Injured_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.591483
# Arunachal Pradesh        2.384863
# Assam                    0.000000
# Bihar                    0.219982
# Chandigarh               0.000000
# Chhattisgarh             1.706779
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.000000
# Gujarat                  0.248181
# Haryana                  0.323453
# Himachal Pradesh         0.000000
# Jammu & Kashmir          0.000000
# Jharkhand                0.227354
# Karnataka                0.530319
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.503946
# Maharashtra              0.126363
# Manipur                  2.206041
# Meghalaya                0.438169
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.023824
# Puducherry               0.000000
# ...

# %%
# Falling of boulders-Number of Persons-Injured - 2014

State_UT = df5.groupby('States/UTs')['Falling of boulders-Number of Persons-Injured - 2014 per 1L people'].sum()
print(State_UT)
Falling_of_boulders_number_of_Person_injured_2014 = df5['Falling of boulders-Number of Persons-Injured - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Injured_number_per_lakh = (Falling_of_boulders_number_of_Person_injured_2014 / population) * 100000
print(Injured_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.022896
# Arunachal Pradesh        0.000000
# Assam                    0.000000
# Bihar                    0.055716
# Chandigarh               0.000000
# Chhattisgarh             0.148756
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.000000
# Gujarat                  0.000000
# Haryana                  0.220895
# Himachal Pradesh         0.000000
# Jammu & Kashmir          0.000000
# Jharkhand                0.072753
# Karnataka                0.065471
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.023407
# Maharashtra              0.056953
# Manipur                  0.035017
# Meghalaya                0.134821
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.021442
# Puducherry               0.000000
# ...

# %%
# Other causes/causes not known-Number of Persons-Injured - 2014

State_UT = df5.groupby('States/UTs')['Other causes/causes not known-Number of Persons-Injured - 2014 per 1L people'].sum()
print(State_UT)
Other_Causes_not_known_number_of_Person_Injured_2014 = df5['Other causes/causes not known-Number of Persons-Injured - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Injured_number_per_lakh = (Other_Causes_not_known_number_of_Person_Injured_2014 / population) * 100000
print(Injured_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.     0.000000
# Andhra Pradesh            3.085251
# Arunachal Pradesh         3.902504
# Assam                     0.112159
# Bihar                     0.715662
# Chandigarh                0.000000
# Chhattisgarh              5.562689
# Dadra & Nagar Haveli      0.000000
# Daman & Diu               0.000000
# Delhi                     0.000000
# Goa                       5.690603
# Gujarat                   1.542033
# Haryana                   1.242532
# Himachal Pradesh          0.000000
# Jammu & Kashmir          13.563185
# Jharkhand                 1.915840
# Karnataka                 5.049489
# Kerala                    0.000000
# Lakshadweep               0.000000
# Madhya Pradesh            5.643921
# Maharashtra               2.115252
# Manipur                  22.340547
# Meghalaya                 5.493970
# Mizoram                   0.000000
# Nagaland                  0.000000
# Odisha                    0.069090
# ...

# %% [markdown]
# # **Q-17 Number of ACCIDENTS for each reason per 1L people of that state**

# %%
## Fault of Driver-Total No. of Road Accidents - 2014

State_UT = df5.groupby('States/UTs')['Fault of Driver-Total No. of Road Accidents - 2014 per 1L people'].sum()
print(State_UT)
Fault_of_Driver_Number_of_Person_Accident_2014 = df5['Fault of Driver-Total No. of Road Accidents - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Accidents_number_per_lakh = (Fault_of_Driver_Number_of_Person_Accident_2014/ population) * 100000
print(Accidents_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.     57.280842
# Andhra Pradesh            40.753165
# Arunachal Pradesh          2.168058
# Assam                     22.095410
# Bihar                      4.810784
# Chandigarh                34.961391
# Chhattisgarh              35.654451
# Dadra & Nagar Haveli      25.312110
# Daman & Diu               16.033086
# Delhi                      0.000000
# Goa                      260.190807
# Gujarat                   31.345295
# Haryana                   32.376831
# Himachal Pradesh          42.770142
# Jammu & Kashmir           28.816785
# Jharkhand                  8.975955
# Karnataka                 57.956998
# Kerala                   108.609034
# Lakshadweep                1.551037
# Madhya Pradesh            56.831631
# Maharashtra               42.925283
# Manipur                    0.000000
# Meghalaya                  0.842633
# Mizoram                   10.390027
# Nagaland                  10.664634
# ...

# %%
## Fault of Driver of other vehicles-Total No. of Road Accidents - 2014

State_UT = df5.groupby('States/UTs')['Fault of Driver of other vehicles-Total No. of Road Accidents - 2014 per 1L people'].sum()
print(State_UT)
Driver_of_other_vehicles_total_Person_Accident_2014 = df5['Fault of Driver of other vehicles-Total No. of Road Accidents - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Accidents_number_per_lakh = (Driver_of_other_vehicles_total_Person_Accident_2014 / population) * 100000
print(Accidents_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.549507
# Arunachal Pradesh        1.445372
# Assam                    0.006409
# Bihar                    0.584057
# Chandigarh               0.000000
# Chhattisgarh             2.842021
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.000000
# Gujarat                  0.744544
# Haryana                  1.798713
# Himachal Pradesh         0.320485
# Jammu & Kashmir          3.029988
# Jharkhand                1.085239
# Karnataka                4.998748
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           3.049838
# Maharashtra              6.469449
# Manipur                  0.000000
# Meghalaya                1.348214
# Mizoram                  1.640531
# Nagaland                 3.689660
# Odisha                   0.131033
# Puducherry               0.000000
# ...

# %%
## Fault of Pedestrian-Total No. of Road Accidents - 2014

State_UT = df5.groupby('States/UTs')['Fault of Pedestrian-Total No. of Road Accidents - 2014 per 1L people'].sum()
print(State_UT)
Fault_of_Pedestrain_Number_of_Person_Accident_2014 = df5['Fault of Pedestrian-Total No. of Road Accidents - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Accidents_number_per_lakh = (Fault_of_Pedestrain_Number_of_Person_Accident_2014 / population) * 100000
print(Accidents_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.     0.000000
# Andhra Pradesh            0.446474
# Arunachal Pradesh         0.000000
# Assam                     0.461456
# Bihar                     0.274737
# Chandigarh                0.000000
# Chhattisgarh              0.571536
# Dadra & Nagar Haveli      0.000000
# Daman & Diu               0.000000
# Delhi                     0.000000
# Goa                      11.998259
# Gujarat                   2.501667
# Haryana                   1.372702
# Himachal Pradesh          0.000000
# Jammu & Kashmir           1.778125
# Jharkhand                 0.924575
# Karnataka                 0.548324
# Kerala                    0.000000
# Lakshadweep               0.000000
# Madhya Pradesh            0.209289
# Maharashtra               0.297221
# Manipur                   0.000000
# Meghalaya                 1.011160
# Mizoram                   0.000000
# Nagaland                  0.000000
# Odisha                    0.214417
# ...

# %%
## Defect in Condition of Motor Vehicle-Total No. of Road Accidents - 2014

State_UT = df5.groupby('States/UTs')['Defect in Condition of Motor Vehicle-Total No. of Road Accidents - 2014 per 1L people'].sum()
print(State_UT)
defect_in_condition_of_motor_vehicle_Number_of_Person_Accidents_2014 = df5['Defect in Condition of Motor Vehicle-Total No. of Road Accidents - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Accidents_number_per_lakh = (defect_in_condition_of_motor_vehicle_Number_of_Person_Accidents_2014 / population) * 100000
print(Accidents_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.127837
# Arunachal Pradesh        1.228566
# Assam                    0.000000
# Bihar                    0.519695
# Chandigarh               0.000000
# Chhattisgarh             2.630631
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      1.165545
# Gujarat                  0.266381
# Haryana                  0.650850
# Himachal Pradesh         1.077994
# Jammu & Kashmir          2.719016
# Jharkhand                0.863947
# Karnataka                1.024629
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           2.291165
# Maharashtra              0.442272
# Manipur                  4.622182
# Meghalaya                2.527900
# Mizoram                  0.000000
# Nagaland                 1.061409
# Odisha                   0.066708
# Puducherry               0.000000
# ...

# %%
## Defect in Road Condition-Total No. of Road Accidents - 2014

State_UT = df5.groupby('States/UTs')['Defect in Road Condition-Total No. of Road Accidents - 2014 per 1L people'].sum()
print(State_UT)
defect_in_condition_of_total_road_Accidents_2014 = df5['Defect in Road Condition-Total No. of Road Accidents - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Accidents_number_per_lakh = (defect_in_condition_of_total_road_Accidents_2014 / population) * 100000
print(Accidents_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.543783
# Arunachal Pradesh        1.084029
# Assam                    0.000000
# Bihar                    0.428436
# Chandigarh               0.000000
# Chhattisgarh             1.722437
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.068561
# Gujarat                  0.335872
# Haryana                  0.556181
# Himachal Pradesh         0.364187
# Jammu & Kashmir          0.901023
# Jharkhand                0.676001
# Karnataka                0.291348
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           1.991000
# Maharashtra              0.339045
# Manipur                  2.836339
# Meghalaya                1.011160
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.061943
# Puducherry               0.000000
# ...

# %%
## Weather Condition-Total No. of Road Accidents - 2014

State_UT = df5.groupby('States/UTs')['Weather Condition-Total No. of Road Accidents - 2014 per 1L people'].sum()
print(State_UT)
Weather_condition_of_Total_Road_Accidents_2014= df5['Weather Condition-Total No. of Road Accidents - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Accidents_number_per_lakh = (Weather_condition_of_Total_Road_Accidents_2014 / population) * 100000
print(Accidents_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.114481
# Arunachal Pradesh        1.662178
# Assam                    0.000000
# Bihar                    0.392894
# Chandigarh               0.000000
# Chhattisgarh             0.829902
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.068561
# Gujarat                  0.320981
# Haryana                  0.500957
# Himachal Pradesh         0.000000
# Jammu & Kashmir          0.159473
# Jharkhand                0.615373
# Karnataka                1.111379
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.742150
# Maharashtra              0.090768
# Manipur                  3.851818
# Meghalaya                0.943749
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.026207
# Puducherry               0.000000
# ...

# %%
## Fault of Passenger-Total No. of Road Accidents - 2014

State_UT = df5.groupby('States/UTs')['Fault of Passenger-Total No. of Road Accidents - 2014 per 1L people'].sum()
print(State_UT)
Fault_of_Passenger_Total_Number_of_Person_Accidents_2014= df5['Fault of Passenger-Total No. of Road Accidents - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Accidents_number_per_lakh = (Fault_of_Passenger_Total_Number_of_Person_Accidents_2014 / population) * 100000
print(Accidents_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.129745
# Arunachal Pradesh        0.794954
# Assam                    0.000000
# Bihar                    0.377524
# Chandigarh               0.000000
# Chhattisgarh             1.119584
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.000000
# Gujarat                  0.221709
# Haryana                  0.607460
# Himachal Pradesh         0.000000
# Jammu & Kashmir          0.000000
# Jharkhand                0.163695
# Karnataka                0.225877
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.722874
# Maharashtra              0.084539
# Manipur                  1.645777
# Meghalaya                1.112276
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.030971
# Puducherry               0.000000
# ...

# %%
## Poor light-Total No. of Road Accidents - 2014

State_UT = df5.groupby('States/UTs')['Poor light-Total No. of Road Accidents - 2014 per 1L people'].sum()
print(State_UT)
Poor_Light_Number_of_Road_Accidents_2014= df5['Poor light-Total No. of Road Accidents - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Accidents_number_per_lakh = (Poor_Light_Number_of_Road_Accidents_2014 / population) * 100000
print(Accidents_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.364430
# Arunachal Pradesh        2.457132
# Assam                    0.000000
# Bihar                    0.316044
# Chandigarh               0.000000
# Chhattisgarh             1.377950
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.205684
# Gujarat                  0.254799
# Haryana                  0.520680
# Himachal Pradesh         0.000000
# Jammu & Kashmir          0.000000
# Jharkhand                0.239480
# Karnataka                0.404286
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.574168
# Maharashtra              0.133482
# Manipur                  1.050496
# Meghalaya                1.348214
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.033354
# Puducherry               0.000000
# ...

# %%
## Falling of boulders-Total No. of Road Accidents - 2014

State_UT = df5.groupby('States/UTs')['Falling of boulders-Total No. of Road Accidents - 2014 per 1L people'].sum()
print(State_UT)
Falling_of_boulders_Total_number_of_Road_Accidents_2014= df5['Falling of boulders-Total No. of Road Accidents - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Accidents_number_per_lakh = (Falling_of_boulders_Total_number_of_Road_Accidents_2014/ population) * 100000
print(Accidents_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.    0.000000
# Andhra Pradesh           0.011448
# Arunachal Pradesh        0.000000
# Assam                    0.000000
# Bihar                    0.078771
# Chandigarh               0.000000
# Chhattisgarh             0.101780
# Dadra & Nagar Haveli     0.000000
# Daman & Diu              0.000000
# Delhi                    0.000000
# Goa                      0.000000
# Gujarat                  0.004964
# Haryana                  0.512791
# Himachal Pradesh         0.000000
# Jammu & Kashmir          0.000000
# Jharkhand                0.072753
# Karnataka                0.068745
# Kerala                   0.000000
# Lakshadweep              0.000000
# Madhya Pradesh           0.097760
# Maharashtra              0.063182
# Manipur                  0.035017
# Meghalaya                0.404464
# Mizoram                  0.000000
# Nagaland                 0.000000
# Odisha                   0.019059
# Puducherry               0.000000
# ...

# %%
## Other causes/causes not known-Total No. of Road Accidents - 2014

State_UT = df5.groupby('States/UTs')['Other causes/causes not known-Total No. of Road Accidents - 2014 per 1L people'].sum()
print(State_UT)
Other_Causes_not_known_number_of_Person_Road_Accidents_2014= df5['Other causes/causes not known-Total No. of Road Accidents - 2014'].sum()
df5['Population'] = pd.to_numeric(df5['Population'])
population = df5['Population'].sum()

Accidents_number_per_lakh = (Other_Causes_not_known_number_of_Person_Road_Accidents_2014/ population) * 100000
print(Accidents_number_per_lakh)
# Out:
# States/UTs
# Andaman & Nicobar Is.     0.000000
# Andhra Pradesh            2.919254
# Arunachal Pradesh         2.457132
# Assam                     0.137796
# Bihar                     0.922195
# Chandigarh                0.000000
# Chhattisgarh              6.075506
# Dadra & Nagar Haveli      0.000000
# Daman & Diu               0.000000
# Delhi                     0.000000
# Goa                       9.804291
# Gujarat                   2.197232
# Haryana                   2.070886
# Himachal Pradesh          0.000000
# Jammu & Kashmir           7.016815
# Jharkhand                 1.912809
# Karnataka                 3.903737
# Kerala                    0.000000
# Lakshadweep               0.000000
# Madhya Pradesh            5.966116
# Maharashtra               3.834506
# Manipur                  11.555455
# Meghalaya                 7.482585
# Mizoram                   0.000000
# Nagaland                  0.000000
# Odisha                    0.090532
# ...

# %% [markdown]
# # **Q-18 Total number of ROAD ACCIDENTS, INJURIES, DEATHS due to FAULT OF THE**
# # ** DRIVER per 1Lpopulation of that state.**

# %%
total_accidents = df5['Fault of Driver-Total No. of Road Accidents - 2014'].sum() + df5['Fault of Driver-Number of Persons-Killed - 2014'].sum()\
+ df5['Fault of Driver-Number of Persons-Injured - 2014'].sum()
total_Injured = df5['Fault of Driver-Number of Persons-Injured - 2014'].sum()
total_deathes_per_lakh = df5['Fault of Driver-Number of Persons-Killed - 2014'].sum()
total_population = df5['Population'].sum()

total_accidents_per_lakh = (total_accidents / total_population) * 100000
total_Injured_per_lakh = (total_Injured / total_population) * 100000
total_deathes_per_lakh = (total_deathes_per_lakh / total_population) * 100000

print("Total Accidents Fault of Driver per 1 Lakh Population:", total_accidents_per_lakh)
print("Total Injured Fault of Driver per 1 Lakh Population:", total_Injured_per_lakh)
print("Total Deaths Fault of Driver per 1 Lakh Population:", total_deathes_per_lakh)
# Out:
# Total Accidents Fault of Driver per 1 Lakh Population: 72.78233153280576
# Total Injured Fault of Driver per 1 Lakh Population: 32.71009504589049
# Total Deaths Fault of Driver per 1 Lakh Population: 8.555318955944278

# %% [markdown]
# # Q- 19 Total number of ROAD ACCIDENTS, INJURIES, DEATHS due to the FAULT OF
# # DRIVER'S FROM OTHER VEHICLES per 1L people of that state **bold text**.

# %%
Total_Road_Accidents = df5['Fault of Driver of other vehicles-Total No. of Road Accidents - 2014'].sum()\
+df5['Fault of Driver of other vehicles-Number of Persons-Killed - 2014'].sum()\
+df5['Fault of Driver of other vehicles-Number of Persons-Injured - 2014'].sum()
Total_Injured = df5['Fault of Driver of other vehicles-Number of Persons-Injured - 2014'].sum()
Total_Deaths = df5['Fault of Driver of other vehicles-Number of Persons-Killed - 2014'].sum()
Total_population = df5['Population'].sum()


Total_Road_Accidents_per_lakh = (Total_Road_Accidents / Total_population) * 100000
total_Injured_per_lakh = (Total_Injured / Total_population) * 100000
total_deathes_per_lakh = (Total_Deaths / Total_population) * 100000

print("Total Road Accidents from other vehicle per 1 Lakh Population:", Total_Road_Accidents_per_lakh)
print("Total Injured from other vehicle per 1 Lakh Population:", total_Injured_per_lakh)
print("Total Deaths from other vehicle per 1 Lakh Population:", total_deathes_per_lakh)
# Out:
# Total Road Accidents from other vehicle per 1 Lakh Population: 3.5192416541593525
# Total Injured from other vehicle per 1 Lakh Population: 1.3428652433036044
# Total Deaths from other vehicle per 1 Lakh Population: 0.4403314009965683

# %% [markdown]
# **Q- 20** Total number of ROAD ACCIDENTS, INJURIES, DEATHS due to the FAULT OF
#  PEDESTRIANS per 1Lpeople of that state.

# %%
Total_Road_Accidents = df5['Fault of Pedestrian-Total No. of Road Accidents - 2014'].sum()\
+df5['Fault of Pedestrian-Number of Persons-Killed - 2014'].sum()\
+df5['Fault of Pedestrian-Number of Persons-Injured - 2014'].sum()
Total_Injured = df5['Fault of Pedestrian-Number of Persons-Injured - 2014'].sum()
Total_Deaths = df5['Fault of Pedestrian-Number of Persons-Killed - 2014'].sum()
Total_population = df5['Population'].sum()

Total_Road_Accidents_per_lakh = (Total_Road_Accidents / Total_population) * 100000
total_Injured_per_lakh = (Total_Injured / Total_population) * 100000
total_deathes_per_lakh = (Total_Deaths / Total_population) * 100000

print("Total Road Accidents from Pedestrian per 1 Lakh Population:", Total_Road_Accidents_per_lakh)
print("Total Injured from Pedestrian per 1 Lakh Population:", total_Injured_per_lakh)
print("Total Deaths from Pedestrian per 1 Lakh Population:", total_deathes_per_lakh)
# Out:
# Total Road Accidents from Pedestrian per 1 Lakh Population: 1.3369608940173423
# Total Injured from Pedestrian per 1 Lakh Population: 0.5264850046665295
# Total Deaths from Pedestrian per 1 Lakh Population: 0.2124734144563233

# %% [markdown]
# **Q- 21** Total number of ROAD ACCIDENTS, INJURIES, DEATHS due to the DEFECTS IN
#  THE VEHICLE per 1L people of that state.

# %%
Total_Road_Accidents = df5['Defect in Condition of Motor Vehicle-Total No. of Road Accidents - 2014'].sum()\
+df5['Defect in Condition of Motor Vehicle-Number of Persons-Killed - 2014'].sum()\
+df5['Defect in Condition of Motor Vehicle-Number of Persons-Injured - 2014'].sum()

Total_Deaths = df5['Defect in Condition of Motor Vehicle-Number of Persons-Killed - 2014'].sum()
Total_Injured = df5['Defect in Condition of Motor Vehicle-Number of Persons-Injured - 2014'].sum()
Total_population = df5['Population'].sum()



Total_Road_Accidents_per_lakh = (Total_Road_Accidents / Total_population) * 100000
Total_Injured_per_lakh = (Total_Injured / Total_population) * 100000
Total_deathes_per_lakh = (Total_Deaths / Total_population) * 100000

print("Total Road Accidents from Defect in Condition of Motor Vehicle':", Total_Road_Accidents_per_lakh)
print("Total Injured from Defect in Condition of Motor Vehicle':", Total_Injured_per_lakh)
print("Total Deaths from Defect in Condition of Motor Vehicle':", Total_deathes_per_lakh)
# Out:
# Total Road Accidents from Defect in Condition of Motor Vehicle': 1.762489841873705
# Total Injured from Defect in Condition of Motor Vehicle': 0.7027007249142591
# Total Deaths from Defect in Condition of Motor Vehicle': 0.2950511446148865

# %% [markdown]
# **Q- 21** Total number of ROAD ACCIDENTS, INJURIES, DEATHS due to DEFECTS IN THE
#  ROAD CONDITION per 1L people of that state.

# %%
Total_Road_Accidents = df5['Defect in Road Condition-Total No. of Road Accidents - 2014'].sum()\
+df5['Defect in Road Condition-Number of Persons-Killed - 2014'].sum()\
+df5['Defect in Road Condition-Number of Persons-Injured - 2014'].sum()

Total_Deaths =df5['Defect in Road Condition-Number of Persons-Killed - 2014'].sum()
Total_Injured = df5['Defect in Road Condition-Number of Persons-Injured - 2014'].sum()
Total_population = df5['Population'].sum()

Total_Road_Accidents_per_lakh = (Total_Road_Accidents / Total_population) * 100000
Total_Injured_per_lakh = (Total_Injured / Total_population) * 100000
Total_deathes_per_lakh = (Total_Deaths / Total_population) * 100000

print("Total Road Accidents from Defect in Road Condition':", Total_Road_Accidents_per_lakh)
print("Total Injured from Defect in Road Condition':", Total_Injured_per_lakh)
print("Total Deaths from Defect in Road Condition':", Total_deathes_per_lakh)
# Out:
# Total Road Accidents from Defect in Road Condition': 1.6062324854105225
# Total Injured from Defect in Road Condition': 0.6233662288706847
# Total Deaths from Defect in Road Condition': 0.2879825574411928

# %%
Total_deaths_road_defects = df5[['States/UTs',
                         'Defect in Road Condition-Total No. of Road Accidents - 2014 per 1L people',
                         'Defect in Road Condition-Number of Persons-Injured - 2014 per 1L people',
                         'Defect in Road Condition-Number of Persons-Killed - 2014 per 1L people']]
Total_deaths_road_defects
# Out:
#                States/UTs  \
# 0          Andhra Pradesh
# 1       Arunachal Pradesh
# 2                   Assam
# 3                   Bihar
# 4            Chhattisgarh
# 5                     Goa
# 6                 Gujarat
# 7                 Haryana
# 8        Himachal Pradesh
# 9         Jammu & Kashmir
# 10              Jharkhand
# 11              Karnataka
# 12                 Kerala
# 13         Madhya Pradesh
# 14            Maharashtra
# 15                Manipur
# 16              Meghalaya
# 17                Mizoram
# 18               Nagaland
# 19                 Odisha
# 20                 Punjab
# 21              Rajasthan
# 22                 Sikkim
# 23             Tamil Nadu
# 24              Telangana
# 25                Tripura
# 26            Uttarakhand
# 27          Uttar Pradesh
# 28            West Bengal
# 29  Andaman & Nicobar Is.
# 30             Chandigarh
# 31   Dadra & Nagar Haveli
# 32            Daman & Diu
# 33                 Delhi
# ...

# %% [markdown]
# **Q-23** Total number of ROAD ACCIDENTS, INJURIES, DEATHS due to WEATHER
#  CONDITION per1Lpeople of that state.

# %%
Total_deaths_weather_conditions = df5[['States/UTs',
                               'Weather Condition-Total No. of Road Accidents - 2014 per 1L people',
                               'Weather Condition-Number of Persons-Injured - 2014 per 1L people',
                               'Weather Condition-Number of Persons-Killed - 2014 per 1L people']]
Total_deaths_weather_conditions
# Out:
#                States/UTs  \
# 0          Andhra Pradesh
# 1       Arunachal Pradesh
# 2                   Assam
# 3                   Bihar
# 4            Chhattisgarh
# 5                     Goa
# 6                 Gujarat
# 7                 Haryana
# 8        Himachal Pradesh
# 9         Jammu & Kashmir
# 10              Jharkhand
# 11              Karnataka
# 12                 Kerala
# 13         Madhya Pradesh
# 14            Maharashtra
# 15                Manipur
# 16              Meghalaya
# 17                Mizoram
# 18               Nagaland
# 19                 Odisha
# 20                 Punjab
# 21              Rajasthan
# 22                 Sikkim
# 23             Tamil Nadu
# 24              Telangana
# 25                Tripura
# 26            Uttarakhand
# 27          Uttar Pradesh
# 28            West Bengal
# 29  Andaman & Nicobar Is.
# 30             Chandigarh
# 31   Dadra & Nagar Haveli
# 32            Daman & Diu
# 33                 Delhi
# ...

# %%
df6 = pd.read_csv('/content/typeOfVehicle.csv')

# %% [markdown]
# **Q- 24 **Number of Total Accidents for each vehicle type per 1L people of that state.

# %%
States_UTs = df6.groupby('States/UTs')['Two-Wheelers - Number of Road Accidents - Total - 2014 per 1L people'].sum()
print(States_UTs)

States_UTs = df6.groupby('States/UTs')['Auto-Rickshaws - Number of Road Accidents - Total - 2014 per 1L people'].sum()
print(States_UTs)

States_UTs = df6.groupby('States/UTs')['Cars, Jeeps,Taxis - Number of Road Accidents - Total - 2014 per 1L people'].sum()
print(States_UTs)

States_UTs = df6.groupby('States/UTs')['Buses - Number of Road Accidents - Total - 2014 per 1L people'].sum()
print(States_UTs)

States_UTs = df6.groupby('States/UTs')['Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Total - 2014 per 1L people'].sum()
print(States_UTs)

States_UTs = df6.groupby('States/UTs')['Other Motor Vehicles - Number of Road Accidents - Total - 2014 per 1L people'].sum()
print(States_UTs)

States_UTs = df6.groupby('States/UTs')['Other Vehicles/Objects - Number of Road Accidents - Total - 2014 per 1L people'].sum()
print(States_UTs)

# Defining with Popuation

Two_Wheeles_Number_of_Road_Accidents_2014= df6['Two-Wheelers - Number of Road Accidents - Total - 2014'].sum()
df6['Population'] = pd.to_numeric(df6['Population'])
population = df6['Population'].sum()

Accidents_number_per_lakh = (Two_Wheeles_Number_of_Road_Accidents_2014/ population) * 100000
print(Accidents_number_per_lakh)

Auto_Rickshaws_Number_of_Road_Accidents_2014 = df6['Auto-Rickshaws - Number of Road Accidents - Total - 2014'].sum()
df6['Population'] = pd.to_numeric(df6['Population'])
population = df6['Population'].sum()

Accidents_number_per_lakh = (Auto_Rickshaws_Number_of_Road_Accidents_2014/ population) * 100000
print(Accidents_number_per_lakh)

Cars_Jeeps_Taxis_Number_of_Road_Accidents_2014 = df6['Cars, Jeeps,Taxis - Number of Road Accidents - Total - 2014'].sum()
df6['Population'] = pd.to_numeric(df6['Population'])
population = df6['Population'].sum()


Accidents_number_per_lakh = (Cars_Jeeps_Taxis_Number_of_Road_Accidents_2014/ population) * 100000
print(Accidents_number_per_lakh)

Buses_Number_of_Road_Accidents_2014 = df6['Buses - Number of Road Accidents - Total - 2014'].sum()
df6['Population'] = pd.to_numeric(df6['Population'])
population = df6['Population'].sum()

Accidents_number_per_lakh = (Buses_Number_of_Road_Accidents_2014/ population) * 100000
print(Accidents_number_per_lakh)


Trucks_Tempos_MAVs_Tractors_Number_of_Road_Accidents_2014 = df6['Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Total - 2014'].sum()
df6['Population'] = pd.to_numeric(df6['Population'])
population = df6['Population'].sum()

Accidents_number_per_lakh =(Trucks_Tempos_MAVs_Tractors_Number_of_Road_Accidents_2014/ population) * 100000
print(Accidents_number_per_lakh)

Other_Motor_Vehicles_Number_of_Road_Accidents_2014 = df6['Other Motor Vehicles - Number of Road Accidents - Total - 2014'].sum()
df6['Population'] = pd.to_numeric(df6['Population'])
population = df6['Population'].sum()

Accidents_number_per_lakh =(Other_Motor_Vehicles_Number_of_Road_Accidents_2014 / population) * 100000
print(Accidents_number_per_lakh)

Other_Vehicles_Objects_Number_of_Road_Accidents_2014 = df6['Other Vehicles/Objects - Number of Road Accidents - Total - 2014'].sum()
df6['Population'] = pd.to_numeric(df6['Population'])
population = df6['Population'].sum()

Accidents_number_per_lakh =(Other_Vehicles_Objects_Number_of_Road_Accidents_2014 / population) * 100000
print(Accidents_number_per_lakh)

 ## Results
vehicle_accidents = {'Two_Wheelers_Total_Accidents': 'Two-Wheelers - Number of Road Accidents - Total - 2014 per 1L people',
    'Auto_Rickshaws_Total_Accidents': 'Auto-Rickshaws - Number of Road Accidents - Total - 2014 per 1L people',
    'Cars_Jeeps_Taxis_Total_Accidents': 'Cars, Jeeps,Taxis - Number of Road Accidents - Total - 2014 per 1L people',
    'Buses_Total_Accidents': 'Buses - Number of Road Accidents - Total - 2014 per 1L people',
    'Trucks_Tempos_MAVs_Tractors_Total_Accidents': 'Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Total - 2014 per 1L people',
    'Other_Motor_Vehicles_Total_Accidents': 'Other Motor Vehicles - Number of Road Accidents - Total - 2014 per 1L people',
    'Other_Vehicles_Objects_Total_Accidents': 'Other Vehicles/Objects - Number of Road Accidents - Total - 2014 per 1L people'
}
Total_Accidents_per_vehicle_type = df6[['States/UTs']]

for vehicle, column in vehicle_accidents.items():
    Total_Accidents_per_vehicle_type[vehicle] = df6[column]

Total_Accidents_per_vehicle_type
# Out:
# States/UTs
# Andaman & Nicobar Islands     24.173566
# Andhra Pradesh                13.812077
# Arunachal Pradesh              2.457132
# Assam                          4.832470
# Bihar                          1.681085
# Chandigarh                     5.779525
# Chhattisgarh                  18.739334
# Dadra & Nagar Haveli           5.236988
# Daman & Diu                    5.755467
# Delhi                          7.773437
# Goa                          130.746737
# Gujarat                        9.202562
# Haryana                        4.461281
# Himachal Pradesh              11.857934
# Jammu & Kashmir                8.778993
# Jharkhand                      3.607358
# Karnataka                     17.598736
# Kerala                        36.259887
# Lakshadweep                    1.551037
# Madhya Pradesh                27.108447
# Maharashtra                   12.537561
# Manipur                        7.038323
# Meghalaya                      1.516740
# ...

# %% [markdown]
# # **Q- 25 Number of Persons Killed for each vehicle type per 1L people of that state.**

# %%
States_UTs = df6.groupby('States/UTs')['Two-Wheelers - Number of Persons - Killed - 2014 per 1L people'].sum()
print(States_UTs)

States_UTs = df6.groupby('States/UTs')['Auto-Rickshaws - Number of Persons - Killed - 2014 per 1L people'].sum()
print(States_UTs)

States_UTs = df6.groupby('States/UTs')['Cars, Jeeps,Taxis - Number of Persons - Killed - 2014 per 1L people'].sum()
print(States_UTs)


States_UTs = df6.groupby('States/UTs')['Buses - Number of Persons - Killed - 2014 per 1L people'].sum()
print(States_UTs)


States_UTs = df6.groupby('States/UTs')['Trucks, Tempos,MAVs,Tractors - Number of Persons - Killed - 2014 per 1L people'].sum()
print(States_UTs)



States_UTs = df6.groupby('States/UTs')['Other Motor Vehicles - Number of Persons - Killed - 2014 per 1L people'].sum()
print(States_UTs)



States_UTs = df6.groupby('States/UTs')['Other Vehicles/Objects - Number of Persons - Killed - 2014 per 1L people'].sum()
print(States_UTs)

# calculating population

Two_Wheelers_Number_of_Killed_2014= df6['Two-Wheelers - Number of Persons - Killed - 2014'].sum()
df6['Population'] = pd.to_numeric(df6['Population'])
population = df6['Population'].sum()

Killed_number_per_lakh = (Two_Wheelers_Number_of_Killed_2014/ population) * 100000
print(Killed_number_per_lakh)

Auto_Rickshaws_Number_of_Killed_2014 = df6['Auto-Rickshaws - Number of Persons - Killed - 2014'].sum()
df6['Population'] = pd.to_numeric(df6['Population'])
population = df6['Population'].sum()

Killed_number_per_lakh = (Auto_Rickshaws_Number_of_Killed_2014/ population) * 100000
print(Killed_number_per_lakh)

Cars_Jeeps_Taxis_Number_of_killed_2014 = df6['Cars, Jeeps,Taxis - Number of Persons - Killed - 2014'].sum()
df6['Population'] = pd.to_numeric(df6['Population'])
population = df6['Population'].sum()

Killed_number_per_lakh = (Cars_Jeeps_Taxis_Number_of_killed_2014 / population) * 100000
print(Killed_number_per_lakh)

Buses_Number_of_Killed_2014 = df6['Buses - Number of Persons - Killed - 2014'].sum()
df6['Population'] = pd.to_numeric(df6['Population'])
population = df6['Population'].sum()

Killed_number_per_lakh = (Buses_Number_of_Killed_2014 / population) * 100000
print(Killed_number_per_lakh)


Trucks_Tempos_MAVs_Tractors_Number_of_Killed_2014 = df6['Trucks, Tempos,MAVs,Tractors - Number of Persons - Killed - 2014'].sum()
df6['Population'] = pd.to_numeric(df6['Population'])
population = df6['Population'].sum()

Killed_number_per_lakh =(Trucks_Tempos_MAVs_Tractors_Number_of_Killed_2014/ population) * 100000
print(Killed_number_per_lakh)

Other_Motor_Vehicles_Number_of_Killed_2014 = df6['Other Motor Vehicles - Number of Persons - Killed - 2014'].sum()
df6['Population'] = pd.to_numeric(df6['Population'])
population = df6['Population'].sum()

Killed_number_per_lakh=(Other_Motor_Vehicles_Number_of_Killed_2014  / population) * 100000
print(Killed_number_per_lakh)

Other_Vehicles_Objects_Number_of_Killed_2014 = df6['Other Vehicles/Objects - Number of Persons - Killed - 2014'].sum()
df6['Population'] = pd.to_numeric(df6['Population'])
population = df6['Population'].sum()

Killed_number_per_lakh =(Other_Vehicles_Objects_Number_of_Killed_2014  / population) * 100000
print(Killed_number_per_lakh)


killed_By_Vehicle =  {'Two_Wheelers_Killed': 'Two-Wheelers - Number of Persons - Killed - 2014 per 1L people',
    'Auto_Rickshaws_Killed': 'Auto-Rickshaws - Number of Persons - Killed - 2014 per 1L people',
    'Cars_Jeeps_Taxis_Killed': 'Cars, Jeeps,Taxis - Number of Persons - Killed - 2014 per 1L people',
    'Buses_Killed': 'Buses - Number of Persons - Killed - 2014 per 1L people',
    'Trucks_Tempos_MAVs_Tractors_Killed': 'Trucks, Tempos,MAVs,Tractors - Number of Persons - Killed - 2014 per 1L people',
    'Other_Motor_Vehicles_Killed': 'Other Motor Vehicles - Number of Persons - Killed - 2014 per 1L people',
    'Other_Vehicles_Objects_Killed': 'Other Vehicles/Objects - Number of Persons - Killed - 2014 per 1L people'
}
Killed_per_vehicle_type = df6[['States/UTs']]

for vehicle, column in killed_By_Vehicle.items():
    Killed_per_vehicle_type[vehicle] = df6[column]

Killed_per_vehicle_type
# Out:
# States/UTs
# Andaman & Nicobar Islands    1.313781
# Andhra Pradesh               3.821742
# Arunachal Pradesh            1.517640
# Assam                        1.720846
# Bihar                        0.787708
# Chandigarh                   1.894926
# Chhattisgarh                 4.407873
# Dadra & Nagar Haveli         4.073213
# Daman & Diu                  3.288838
# Delhi                        0.851802
# Goa                          9.187238
# Gujarat                      2.794521
# Haryana                      1.254366
# Himachal Pradesh             2.461905
# Jammu & Kashmir              2.041255
# Jharkhand                    1.840056
# Karnataka                    4.975833
# Kerala                       2.882710
# Lakshadweep                  0.000000
# Madhya Pradesh               3.104914
# Maharashtra                  3.620044
# Manipur                      1.155546
# Meghalaya                    0.471875
# Mizoram                      1.458249
# ...

# %% [markdown]
# # **Q- 26 Total accidents, fatal accidents, killed and injured for each state per 1L people of that state.**

# %%
Total_Cases= df6[['States/UTs',
                                     'Two-Wheelers - Number of Road Accidents - Fatal - 2014 per 1L people',
                                     'Two-Wheelers - Number of Road Accidents - Total - 2014 per 1L people',
                                     'Two-Wheelers - Number of Persons - Killed - 2014 per 1L people',
                                     'Two-Wheelers - Number of Persons - Injured - 2014 per 1L people']]


Total_Cases['Total_Accidents_per_1L'] = df6[['Two-Wheelers - Number of Road Accidents - Total - 2014 per 1L people',
                                                               'Auto-Rickshaws - Number of Road Accidents - Total - 2014 per 1L people',
                                                               'Cars, Jeeps,Taxis - Number of Road Accidents - Total - 2014 per 1L people',
                                                               'Buses - Number of Road Accidents - Total - 2014 per 1L people',
                                                               'Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Total - 2014 per 1L people',
                                                               'Other Motor Vehicles - Number of Road Accidents - Total - 2014 per 1L people',
                                                               'Other Vehicles/Objects - Number of Road Accidents - Total - 2014 per 1L people']].sum(axis=1)

Total_Cases['Fatal_Accidents_per_1L'] = df6[['Two-Wheelers - Number of Road Accidents - Fatal - 2014 per 1L people',
                                                               'Auto-Rickshaws - Number of Road Accidents - Fatal - 2014 per 1L people',
                                                               'Cars, Jeeps,Taxis - Number of Road Accidents - Fatal - 2014 per 1L people',
                                                               'Buses - Number of Road Accidents - Fatal - 2014 per 1L people',
                                                               'Trucks, Tempos,MAVs,Tractors - Number of Road Accidents - Fatal - 2014 per 1L people',
                                                               'Other Motor Vehicles - Number of Road Accidents - Fatal - 2014 per 1L people',
                                                               'Other Vehicles/Objects - Number of Road Accidents - Fatal - 2014 per 1L people']].sum(axis=1)
Total_Cases['Total_Killed_per_1L'] = df6[['Two-Wheelers - Number of Persons - Killed - 2014 per 1L people',
                                                            'Auto-Rickshaws - Number of Persons - Killed - 2014 per 1L people',
                                                            'Cars, Jeeps,Taxis - Number of Persons - Killed - 2014 per 1L people',
                                                            'Buses - Number of Persons - Killed - 2014 per 1L people',
                                                            'Trucks, Tempos,MAVs,Tractors - Number of Persons - Killed - 2014 per 1L people',
                                                            'Other Motor Vehicles - Number of Persons - Killed - 2014 per 1L people',
                                                            'Other Vehicles/Objects - Number of Persons - Killed - 2014 per 1L people']].sum(axis=1)

Total_Cases['Total_Injured_per_1L'] = df6[['Two-Wheelers - Number of Persons - Injured - 2014 per 1L people',
                                                             'Auto-Rickshaws - Number of Persons - Injured - 2014 per 1L people',
                                                             'Cars, Jeeps,Taxis - Number of Persons - Injured - 2014 per 1L people',
                                                             'Buses - Number of Persons - Injured - 2014 per 1L people',
                                                             'Trucks, Tempos,MAVs,Tractors - Number of Persons - Injured - 2014 per 1L people',
                                                             'Other Motor Vehicles - Number of Persons - Injured - 2014 per 1L people',
                                                             'Other Vehicles/Objects - Number of Persons - Injured - 2014 per 1L people']].sum(axis=1)

final_data = Total_Cases[['States/UTs', 'Total_Accidents_per_1L', 'Fatal_Accidents_per_1L', 'Total_Killed_per_1L', 'Total_Injured_per_1L']]
final_data
# Out:
#                    States/UTs  Total_Accidents_per_1L  Fatal_Accidents_per_1L  \
# 0              Andhra Pradesh               46.631741               13.884582
# 1           Arunachal Pradesh               14.815061                6.648710
# 2                       Assam               22.893344                6.950681
# 3                       Bihar                9.179683                4.327592
# 4                Chhattisgarh               54.104102               13.975229
# 5                         Goa              289.946488               19.402898
# 6                     Gujarat               39.232496               11.686029
# 7                     Haryana               42.111970               16.622316
# 8            Himachal Pradesh               44.547375               12.105582
# 9             Jammu & Kashmir               46.733585                7.064657
# 10                  Jharkhand               15.766275                6.847917
# ...

# %%
df7 = pd.read_excel('/content/timeOfOccurence NEW.xls')

# %%
## Q- 27 Number of Accidents happening in DAY and NIGHT TIME for 2014 and 2016


df7_2014_day = df7[['06-900hrs - Day - 2014', '09-1200hrs - Day - 2014', '12-1500hrs - Day - 2014', '15-1800hrs - Day - 2014']]

df7_2014_night = df7[['06-900hrs - Day - 2014', '09-1200hrs - Day - 2014', '12-1500hrs - Day - 2014', '15-1800hrs - Day - 2014']]

df7_2016_day = df7[['06-900hrs - (Day) - 2016', '09-1200hrs - (Day) - 2016', '12-1500hrs - (Day) - 2016', '15-1800hrs - (Day) - 2016']]

df7_2016_night = df7[['18-2100hrs - (Night) - 2016', '21-2400hrs - (Night) - 2016', '00-300hrs - (Night) - 2016', '03-600hrs - (Night) - 2016']]


Total_Accidents_2014_day = df7_2014_day.sum().sum()
Total_Accidents_2014_night = df7_2014_night.sum().sum()
Total_Accidents_2016_day = df7_2016_day.sum().sum()
Total_Accidents_2016_night = df7_2016_night.sum().sum()

print("Number of Accidents in 2014 Day:")
print(Total_Accidents_2014_day )

print("Number of Accidents in 2016 day:")
print(Total_Accidents_2016_day )

print("Number of Accidents in 2014 night:")
print(Total_Accidents_2014_night )

print("Number of Accidents in 2016 night:")
print(Total_Accidents_2016_night)
# Out:
# Number of Accidents in 2014 Day:
# 584814
# Number of Accidents in 2016 day:
# 579014
# Number of Accidents in 2014 night:
# 584814
# Number of Accidents in 2016 night:
# 382290
